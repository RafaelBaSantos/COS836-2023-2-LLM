# %% [markdown]
# # Importando bibliotecas

# %%
from dotenv import load_dotenv
import os

from langchain.chat_models import ChatOpenAI
from langchain.schema import AIMessage, HumanMessage, SystemMessage
from langchain.prompts.chat import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate, AIMessagePromptTemplate
from langchain import LLMChain

import pandas as pd

# %% [markdown]
# # Inicializando API

# %%
load_dotenv(r'E:\Documentos\Estudos\UFRJ_PESC\3_periodo\llm\projeto final\COS836-2023-2-LLM\src\utils\openai_api_key.env')  # take environment variables from .env.
OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

# %%
chat_t1 = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model_name="gpt-3.5-turbo", temperature=1)

# %%
chat_t0 = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model_name="gpt-3.5-turbo", temperature=0)

# %%
chat_t0_16k = ChatOpenAI(openai_api_key=OPENAI_API_KEY, model_name="gpt-3.5-turbo-16k", temperature=0)

# %% [markdown]
# # Criação do background

# %% [markdown]
# ### Background geral do mundo

# %%
sys_background = """Você é um escritor profissional escrevendo sobre um mundo de RPG.

Ao descrever alguma entidade (localização, objeto, personagem, espécie, condição, conflito, organização, título, mito etc.), forneça nomes específicos e breves descrições.

Você deve considerar os seguintes aspectos, mas nunca falar sobre eles diretamente:
1. O gênero é ficção;
2. O mundo trás um sentimento místico;
3. O tom da história é leve;
4. Masmorras e dragões são temas recorrentes do mundo;
5. O nível de tecnologia é medieval,
6. Magia é vista como algo raro,
7. A atmosfera é empolgante,
8. A história é inspirada nos escritores George R. R. Martin, J. R. R. Tolkien, Matthew Mercer e Brennan Lee Mulligan,
9. A história é inspirada no universo de Dungeons & Dragons e Tormenta 20.
10. A história incorpora acontecimentos contemporâneos de seu universo que tratam de mais ou menos 4 dos seguintes assuntos: Governança e sua influência, Princípios legais e Estado de direito, Provisão de serviços sociais, Dinâmicas econômicas, Equidade na distribuição de riqueza, Práticas agrícolas e comércio, Relações interpessoais influenciadas por raça, classe, gênero ou orientação sexual, Poder e influência militar, Papel e influência da religião, Avanços e influências tecnológicas, Impacto das artes e expressões culturais, Características geográficas, Interações entre civilizações, suas histórias e conflitos, Fundamentos das leis da natureza, Teorias sobre a origem do universo, Histórico das espécies e culturas que habitaram o mundo, Necessidades e interações das diferentes espécies e culturas."""

print(sys_background)
# Out:
# Você é um escritor profissional escrevendo sobre um mundo de RPG.
#
# Ao descrever alguma entidade (localização, objeto, personagem, espécie, condição, conflito, organização, título, mito etc.), forneça nomes específicos e breves descrições.
#
# Você deve considerar os seguintes aspectos, mas nunca falar sobre eles diretamente:
# 1. O gênero é ficção;
# 2. O mundo trás um sentimento místico;
# 3. O tom da história é leve;
# 4. Masmorras e dragões são temas recorrentes do mundo;
# 5. O nível de tecnologia é medieval,
# 6. Magia é vista como algo raro,
# 7. A atmosfera é empolgante,
# 8. A história é inspirada nos escritores George R. R. Martin, J. R. R. Tolkien, Matthew Mercer e Brennan Lee Mulligan,
# 9. A história é inspirada no universo de Dungeons & Dragons e Tormenta 20.
# ...

# %%
# lugar, objeto. 3. O nível de agência dos personagens principais é alto; Inclua uma série de personagens diversos que sirvam como mentores aliados ou inimigos.
usr_background = "Descreva de maneira concisa um mundo original e envolvente. Escreva na estrutura de uma história de ficção."
print(usr_background)
# Out:
# Descreva de maneira concisa um mundo original e envolvente. Escreva na estrutura de uma história de ficção.

# %%
background = chat_t1.predict_messages([SystemMessage(content=sys_bg), HumanMessage(content=usr_bg)]).content

# %%
print(background)
# Out:
# No vasto continente de Anerdaron, onde a magia dança com a realidade, e as lendas se tornam verdades, um grupo de heróis improváveis se une para enfrentar o mal que se espalha como uma sombra sinistra.
#
# Neste mundo místico, onde elfos vivem nas florestas ancestrais e anões dominam as profundezas das montanhas, existe uma cidade misteriosa chamada Luminara. Esta cidade flutua pacificamente sobre um vasto lago cristalino, emanando uma energia pura e mística que atrai viajantes de todas as terras.
#
# Mas mesmo a aura sagrada de Luminara está ameaçada. Uma terrível entidade conhecida como o Devorador das Almas despertou de seu sono profundo e busca consumir todo o poder mágico do mundo. Para detê-lo, os heróis devem embarcar em uma jornada perigosa, atravessando terras esquecidas e enfrentando criaturas lendárias.
#
# ...

# %%
background = """No vasto continente de Altharia, onde a magia flui em cada fio de ar, e auras místicas pintam o céu, um grupo de aventureiros se reúne para enfrentar o perigo que ameaça o reino. Eles são liderados por Sirian, um guerreiro valente e honrado, cuja armadura reluz na luz do sol. Através de masmorras sombrias e cavernas profundas, eles desbravam os caminhos perigosos, buscando por tesouros escondidos, enfrentando monstros lendários e desvendando enigmas antigos.

Entre os desafios encontrados por essa guilda brava e corajosa, destaca-se a Cidadela dos Sonhos, um local misterioso e encantado onde a realidade e os sonhos se entrelaçam. Esta fortaleza é guardada pelos Sussurros, seres etéreos cujas vozes ecoam entre as muralhas de pedra. Dizem as lendas que aqueles que adentram a Cidadela têm suas almas expostas, e apenas os mais puros de coração terão a chance de desvendar os segredos ocultos em seu interior.

Outro desafio que aguarda o grupo é a floresta proibida de Eldreth, onde criaturas fantásticas habitam a sombra das árvores milenares. Lá, em meio à natureza selvagem, um artefato sagrado conhecido como a Pedra da Eternidade está enterrado, e somente aqueles que possuem a benção do Ancião das Árvores podem encontrar seu caminho até ela. Mas o perigo não reside apenas nas criaturas hostis; a floresta também reserva encantamentos e ilusões que testarão a perseverança e a astúcia dos aventureiros.

Enquanto a guilda enfrenta esses desafios, uma guerra se aproxima nas Terras Sombrias, um reino governado pelo cruel Lorde das Sombras. O exército das trevas avança impiedosamente, espalhando caos e destruição por onde passa. Os cidadãos clamam por um líder capaz de enfrentar o mal, e é nesse momento que surge Arlene, uma guerreira destemida e habilidosa, com uma profecia escrita nas estrelas que lhe concede a coragem necessária para enfrentar o Lorde das Sombras no duelo final.

Enquanto isso, as cidades de Altharia estão envolvidas em intrincados jogos políticos, com reis e rainhas disputando poder e influência. A Torre dos Magos, onde os sábios estudam os segredos arcanos, é palco de disputas pelo conhecimento e pela busca pela verdade. Naqueles corredores antigos, segredos são revelados e alianças são formadas, enquanto os aventureiros lutam para conter o avanço das trevas.

Em meio a tudo isso, as diferentes raças e culturas convivem, cada uma com suas tradições e rituais. Elfos sábios e graciosos, anões obstinados e fortes, halflings ágeis e astutos, e várias outras espécies únicas enriquecem o tecido social de Altharia. E, mesmo diante das adversidades, heróis nascem e lendas são escritas.

Bem-vindo a Altharia, onde a coragem é testada, a magia é revelada e a esperança floresce mesmo nas horas mais sombrias. Embarque nessa jornada épica e descubra um mundo de mistérios e maravilhas. Aventure-se, lute pela justiça e defenda a luz em um reino repleto de encantamento e perigo."""

# %% [markdown]
# ### Aprofundando o background em tópicos

# %%
usr_topics = """Quais são os principais tópicos dessa história que poderiam ser melhor desenvolvidos?
Responda com uma lista de tópicos e uma breve explicação de cada um. Não faça mais nenhum comentário."""
print(prompt_ask_topics)
# Out:
# Quais são os principais tópicos dessa história que poderiam ser melhor desenvolvidos?
# Responda com uma lista de tópicos e uma breve explicação de cada um. Não faça mais nenhum comentário.

# %%
topics = chat_t1.predict_messages([SystemMessage(content=sys_background),
                                  HumanMessage(content=usr_background),
                                  AIMessage(content=background),
                                  HumanMessage(content=usr_topics)]).content

# %%
ls_topics = [x for x in topics.content.split("\n") if x != ""]

# %%
ls_topics = ['1. A Cidadela dos Sonhos: Explore as lendas e segredos por trás desse local misterioso onde sonhos e realidade se misturam. Desvende os enigmas e descubra o propósito dessa fortaleza encantada.',
 '2. A Floresta Proibida de Eldreth: Aprofunde-se nas criaturas fantásticas que habitam essa floresta milenar e nas ilusões que desafiam os aventureiros. Descubra mais sobre o Ancião das Árvores e a verdade por trás da Pedra da Eternidade.',
 '3. A guerra nas Terras Sombrias: Contemple a construção dessa guerra iminente entre o exército do Lorde das Sombras e os defensores das terras. Conheça os heróis e vilões envolvidos nesse conflito épico e acompanhe a luta para conter o avanço das trevas.',
 '4. Intrigas políticas e jogos de poder: Adentre nas cidades de Altharia e explore os jogos políticos entre reis, rainhas e outros líderes. Descubra as alianças e traições que moldam o destino do reino.',
 '5. A Torre dos Magos: Desvende os segredos ocultos nessa misteriosa torre onde os sábios estudam a magia e buscam pelo conhecimento arcano. Explore as disputas e rivalidades entre os estudiosos e os mistérios que envolvem essa instituição.',
 '6. Raças e culturas: Aprofunde-se nas diferentes raças e culturas que habitam Altharia, explorando suas tradições, rituais e relações interpessoais influenciadas por raça, classe, gênero ou orientação sexual. ',
 '7. O papel da religião: Descubra a influência das crenças religiosas no mundo de Altharia, explore os diferentes tipos de fé e o papel dos seguidores no enfrentamento do mal.',
 '8. A origem do mundo de Altharia: Explore teorias sobre a origem do universo e as leis da natureza. Descubra antigas histórias sobre as espécies e culturas que habitaram o mundo e como essas histórias afetam o presente.',
 '9. Avanços tecnológicos e sua influência: Analise como os avanços tecnológicos impactam a sociedade de Altharia, desde armas e armaduras a dispositivos mágicos. Explore como essas inovações afetam as dinâmicas econômicas, as práticas agrícolas e o comércio.',
 '10. Arte e expressões culturais: Explore o impacto das artes e das expressões culturais na sociedade de Altharia, desde música e dança até pintura, poesia e literatura. Descubra como essas formas de expressão moldam a identidade cultural das diferentes raças e classes sociais.']

# %%
usr_template_expanded = "Desenvolva detalhadamente o seguinte tópico: {topic}"
usr_expanded = HumanMessagePromptTemplate.from_template(usr_template_expanded)
chat_prompt = ChatPromptTemplate.from_messages([SystemMessage(content=sys_background),
                                                HumanMessage(content=usr_background),
                                                AIMessage(content=background),
                                                usr_expanded])
chain = LLMChain(llm=chat_t1, prompt=chat_prompt)

ls_expanded = []
for topic in ls_topics[:2]:
    local_expanded = chain.run(topic=topic)
    ls_expanded.append(local_expanded)

# %% [markdown]
# ### Salvando informações de background

# %%
import pandas as pd

# %%
df_bg = pd.DataFrame({"topics": ["background geral"] + ls_topics, "content": [background] + ls_expanded})
df_bg.to_csv(r".\files\bg.csv", index=False)

# %% [markdown]
# # Text 2 Graph

# %%
df_bg = pd.read_csv(r".\files\bg.csv")

# %%
### T2G do background geral

# %%
sys_t2g_bg = """Você é um ajudante que cria uma lista de entidades e uma lista de relacionamentos, a partir das informações contidas em um texto.

Cada entidade deve ter o nome, rótulo e uma descrição bem detalhada. O rótulo pode ser um dos seguintes:
1. Loc_assentamento: Lugares físicos, como continentes, cidades, montanhas ou florestas;
2.  Construcao: Construções e formações naturais. Exemplos: casa, masmorra, caverna, castelo;
3. Veiculo: Meios de transporte. Exemplo: carro, navio, bicicleta.
4. Objeto: Itens tangíveis ou documentos. Exemplos: armas, roupas, cartas, livros.
5. Personagem: Indivíduos ou animais em papéis específicos. Exemplos: herói, vilão, guarda, animal de estimação.
6. Especie: Grupos biológicos ou culturais. Exemplos: elfos, humanos, cachorros.
7. Condicao: Estados físicos ou emocionais. Exemplos: doença, inspiração, tristeza.
8. Drama: Desafios ou tensões socioculturais. Exemplos: influência militar, relações de classe, problemas econômicos.
9. Organizacao: Grupos com propósitos comuns. Exemplos: igrejas, governos, seitas.
10. Titulo: Cargos, funções ou status. Exemplos: taberneiro, Rei, General.
11. Mito: Narrativas ou crenças. Exemplos: lendas sobre a origem do universo, mitos de monstros.

Os relacionamentos devem ser representados por trios de sujeito, predicado e objeto, onde o sujeito e o objeto são entidades mapeadas e o predicado pode ter os seguintes rótulos:
1. ESTA_EM: Representa localização ou uso.
2. RELACAO_POSITIVA: Denota uma interação ou vínculo interpessoal positivo.
3. RELACAO_NEGATIVA: Denota uma interação ou vínculo interpessoal negativo.
4. RELACAO_NEUTRA: Denota uma interação ou vínculo interpessoal neutro.
5. AFETADO_POR: Mostra entidades impactadas por condições ou conflitos.
6. MEMBRO_DE: Indica pertencimento a grupos, categorias ou organizações.
7. BASEADO_EM: Liga entidades a histórias, mitos, lendas ou influências culturais.
8. FAMILIAR: Representa laços de descendência ou ancestralidade.
9. PROPRIETARIO_DE: Denota posse direta.
9. SUCEDE: Representa o que vem depois em uma sequência temporal.
10. ANTECEDE: Representa o que vem antes em uma sequência temporal."""

print(sys_t2g_bg)
# Out:
# Você é um programador profissional que lê uma história e escreve uma consulta Cypher para o banco de dados Neo4j.
#
# Todas as entidades presentes no texto devem ser representados como vértices (nodes).
# Os nodes podem ter somente os labels:
# 1. Loc_assentamento: Lugares físicos, como continentes, cidades, montanhas ou florestas;
# 2.  Construcao: Construções e formações naturais. Exemplos: casa, masmorra, caverna, castelo;
# 3. Veiculo: Meios de transporte. Exemplo: carro, navio, bicicleta.
# 4. Objeto: Itens tangíveis ou documentos. Exemplos: armas, roupas, cartas, livros.
# 5. Personagem: Indivíduos ou animais em papéis específicos. Exemplos: herói, vilão, guarda, animal de estimação.
# 6. Especie: Grupos biológicos ou culturais. Exemplos: elfos, humanos, cachorros.
# 7. Condicao: Estados físicos ou emocionais. Exemplos: doença, inspiração, tristeza.
# 8. Drama: Desafios ou tensões socioculturais. Exemplos: influência militar, relações de classe, problemas econômicos.
# ...

# %%
example_usr_t2g_bg ="""No coração de Eldoria, erguia-se a majestosa Cidade de Prata, um assentamento que brilhava como uma joia no horizonte. Suas torres imponentes e ruas de paralelepípedos atraíam pessoas de todas as partes do continente. No entanto, escondido nas profundezas da cidade, havia um labirinto subterrâneo conhecido como a Masmorra das Sombras. Esse local sombrio e perigoso era temido por todos, pois abrigava criaturas malignas e tesouros ocultos.

Para explorar as vastas terras de Eldoria, os aventureiros contavam com o auxílio de um veículo especial: os Dragões de Ébano. Essas majestosas criaturas aladas, com escamas negras e olhos flamejantes, eram capazes de voar pelos céus e transportar os heróis em suas costas.

Dentro da Masmorra das Sombras, os aventureiros encontravam objetos poderosos e misteriosos. Entre eles, destacava-se a Espada da Luz, uma arma lendária capaz de banir as trevas e proteger os inocentes. Além disso, havia também os Pergaminhos da Sabedoria, que continham conhecimentos ancestrais e segredos ocultos.

Entre os heróis que se aventuravam por Eldoria, havia um personagem notável: o Guardião das Florestas. Ele era um elfo sábio e corajoso, conhecido por sua habilidade de se comunicar com os animais e proteger a natureza. Ao seu lado, sempre fiel, estava seu animal de estimação, um lobo branco chamado Aurora.

Em Eldoria, diferentes raças e espécies coexistiam. Além dos elfos, havia também os anões, habilidosos em trabalhos manuais e na forja de armas, e os humanos, versáteis e adaptáveis a qualquer situação. Cada uma dessas raças possuía suas próprias características e culturas únicas.

No entanto, nem tudo era paz em Eldoria. O continente era assolado por uma terrível condição: a Praga das Sombras. Essa doença misteriosa afetava os habitantes, tornando-os fracos e desesperançosos. A cura para essa condição estava escondida em algum lugar de Eldoria, e os heróis se aventuravam em busca dela.

Além da Praga das Sombras, Eldoria enfrentava conflitos e dramas constantes. A influência militar do Império das Chamas, uma organização poderosa e expansionista, ameaçava a paz do continente. As relações de classe também eram tensas, com a elite nobre dominando os recursos e o poder econômico.

Para enfrentar esses desafios, várias organizações foram formadas em Eldoria. A Ordem dos Guardiões, liderada pelo Guardião das Florestas, era uma seita de guerreiros dedicados a proteger os inocentes e combater as forças do mal. Já a Irmandade dos Sábios era uma organização de estudiosos e magos que buscavam desvendar os segredos da magia e preservar o conhecimento ancestral.

Dentro desse mundo repleto de aventuras, havia também diversas profissões e títulos. Os taberneiros, por exemplo, eram responsáveis por fornecer abrigo e comida aos aventureiros cansados. Já os Reis e Rainhas governavam os reinos com sabedoria e justiça, enquanto os Generais lideravam os exércitos na defesa do continente.

Eldoria também era palco de histórias e mitos fascinantes. Entre eles, destacava-se a lenda do Dragão Primordial, uma criatura ancestral que teria criado o mundo com seu sopro de fogo. Além disso, havia também mitos sobre monstros terríveis que habitavam as profundezas da Masmorra das Sombras.
"""
print(example_usr_t2g_bg)
# Out:
# No coração de Eldoria, erguia-se a majestosa Cidade de Prata, um assentamento que brilhava como uma joia no horizonte. Suas torres imponentes e ruas de paralelepípedos atraíam pessoas de todas as partes do continente. No entanto, escondido nas profundezas da cidade, havia um labirinto subterrâneo conhecido como a Masmorra das Sombras. Esse local sombrio e perigoso era temido por todos, pois abrigava criaturas malignas e tesouros ocultos.
#
# Para explorar as vastas terras de Eldoria, os aventureiros contavam com o auxílio de um veículo especial: os Dragões de Ébano. Essas majestosas criaturas aladas, com escamas negras e olhos flamejantes, eram capazes de voar pelos céus e transportar os heróis em suas costas.
#
# ...

# %%
example_assist_t2g_bg = """Eldoria
   - Rótulo: Loc_assentamento
   - Descrição: Continente com vastas terras.

Cidade de Prata
   - Rótulo: Loc_assentamento
   - Descrição: A Cidade de Prata é um assentamento majestoso localizado no coração de Eldoria. Suas torres imponentes e ruas de paralelepípedos atraem pessoas de todas as partes do continente. É considerada uma joia no horizonte.

Masmorra das Sombras
   - Rótulo: Construcao
   - Descrição: A Masmorra das Sombras é um labirinto subterrâneo localizado nas profundezas da Cidade de Prata. É um local sombrio e perigoso, temido por todos, pois abriga criaturas malignas e tesouros ocultos.

Dragões de Ébano
   - Rótulo: Veiculo
   - Descrição: Os Dragões de Ébano são majestosas criaturas aladas, com escamas negras e olhos flamejantes. São utilizados como meio de transporte pelos aventureiros de Eldoria, sendo capazes de voar pelos céus e transportar os heróis em suas costas.

Espada da Luz
   - Rótulo: Objeto
   - Descrição: A Espada da Luz é uma arma lendária encontrada na Masmorra das Sombras. É capaz de banir as trevas e proteger os inocentes. Possui um poder místico e é muito cobiçada pelos aventureiros.

Pergaminhos da Sabedoria
   - Rótulo: Objeto
   - Descrição: Os Pergaminhos da Sabedoria são documentos encontrados na Masmorra das Sombras. Contêm conhecimentos ancestrais e segredos ocultos, sendo muito valiosos para os estudiosos e magos de Eldoria.

Guardião das Florestas
   - Rótulo: Personagem
   - Descrição: O Guardião das Florestas é um elfo sábio e corajoso. É conhecido por sua habilidade de se comunicar com os animais e proteger a natureza. Lidera a Ordem dos Guardiões, uma seita de guerreiros dedicados a combater as forças do mal.

Aurora
   - Rótulo: Personagem
   - Descrição: Aurora é um lobo branco e animal de estimação do Guardião das Florestas. Sempre fiel ao seu mestre, acompanha-o em suas aventuras por Eldoria.

Elfos
   - Rótulo: Especie
   - Descrição: Os elfos são uma raça de seres mágicos em Eldoria. São conhecidos por sua sabedoria e habilidades místicas. Possuem uma conexão especial com a natureza e são capazes de se comunicar com os animais.

Anões
   - Rótulo: Especie
   - Descrição: Os anões são uma raça de seres habilidosos em trabalhos manuais e na forja de armas. São conhecidos por sua resistência e força física. Possuem uma cultura única e são muito respeitados em Eldoria.

Humanos
    - Rótulo: Especie
    - Descrição: Os humanos são uma raça versátil e adaptável em Eldoria. São capazes de se adaptar a qualquer situação e possuem uma grande diversidade cultural. São considerados os mais numerosos entre as raças.

Praga das Sombras
    - Rótulo: Condicao
    - Descrição: A Praga das Sombras é uma doença misteriosa que afeta os habitantes de Eldoria. Torna as pessoas fracas e desesperançosas. A cura para essa condição está escondida em algum lugar do continente.

Conflito do Império das Chamas
	- Rótulo: Drama
	- Descrição: Uma organização poderosa e expansionista que ameaça a paz do continente.

Império das Chamas
    - Rótulo: Organizacao
    - Descrição: O Império das Chamas é uma organização militar poderosa e expansionista em Eldoria. Sua influência ameaça a paz do continente. Possui um exército bem treinado e busca dominar os recursos e o poder econômico.

Ordem dos Guardiões
    - Rótulo: Organizacao
    - Descrição: A Ordem dos Guardiões é uma seita de guerreiros liderada pelo Guardião das Florestas. Seu objetivo é proteger os inocentes e combater as forças do mal em Eldoria. São conhecidos por sua coragem e habilidades de combate.

Irmandade dos Sábios
    - Rótulo: Organizacao
    - Descrição: A Irmandade dos Sábios é uma organização de estudiosos e magos em Eldoria. Buscam desvendar os segredos da magia e preservar o conhecimento ancestral. São considerados os guardiões do conhecimento em Eldoria.

Elite Nobre
    - Rótulo: Organizacao
    - Descrição: Grupo de nobres que domina os recursos e o poder econômico.

Taberneiro
    - Rótulo: Titulo
    - Descrição: O taberneiro é responsável por fornecer abrigo e comida aos aventureiros em Eldoria. É uma profissão importante, pois os aventureiros cansados precisam de um local para descansar e se recuperar.

Rei/Rainha
    - Rótulo: Titulo
    - Descrição: O Rei/Rainha é o governante de um reino em Eldoria. São responsáveis por tomar decisões importantes e governar com sabedoria e justiça. Possuem um grande poder político e são respeitados por seus súditos.

General
    - Rótulo: Titulo
    - Descrição: O General é um título dado ao líder de um exército em Eldoria. São responsáveis por liderar as tropas na defesa do continente. Possuem habilidades estratégicas e são respeitados por sua coragem e liderança.

Lenda do Dragão Primordial
    - Rótulo: Mito
    - Descrição: O Dragão Primordial é uma criatura ancestral em Eldoria. Segundo a lenda, teria criado o mundo com seu sopro de fogo. É considerado uma figura divina e possui um papel importante nas crenças e mitos do continente.

Cidade de Prata ESTA_EM Eldoria
Masmorra das Sombras ESTA_EM Cidade de Prata
Dragões de Ébano ESTA_EM Eldoria
Espada da Luz ESTA_EM Masmorra das Sombras
Pergaminhos da Sabedoria ESTA_EM Masmorra das Sombras
Guardião das Florestas MEMBRO_DE Ordem dos Guardiões
Guardião das Florestas PROPRIETARIO_DE Aurora
Eldoria AFETADO_POR Praga das Sombras
Eldoria AFETADO_POR Conflito do Império das Chamas
Império das Chamas BASEADO_EM Conflito do Império das Chamas
Taberneiro ESTA_EM Cidade de Prata
Rei/Rainha ESTA_EM Eldoria
General ESTA_EM Eldoria
Eldoria BASEADO_EM Lenda do Dragão Primordial
Ordem dos Guardiões RELACAO_POSITIVA Cidade de Prata
Irmandade dos Sábios RELACAO_POSITIVA Cidade de Prata"""
print(example_assist_t2g_bg)
# Out:
# CREATE (eldoria:Loc_assentamento {nome: "Eldoria", descrição: "Continente com vastas terras"}),
# (cidade:Loc_assentamento {nome: "Cidade de Prata", descrição: "Um assentamento majestoso que brilha como uma joia no horizonte"}),
# (masmorra:Construcao {nome: "Masmorra das Sombras", descrição: "Um labirinto subterrâneo sombrio e perigoso, habitado por criaturas malignas e tesouros ocultos"}),
# (dragao:Veiculo {nome: "Dragões de Ébano", descrição: "Majestosas criaturas aladas com escamas negras e olhos flamejantes, capazes de voar pelos céus e transportar os heróis"}),
# (espada:Objeto {nome: "Espada da Luz", descrição: "Uma arma lendária capaz de banir as trevas e proteger os inocentes"}),
# (pergaminhos:Objeto {nome: "Pergaminhos da Sabedoria", descrição: "Conhecimentos ancestrais e segredos ocultos"}),
# (guardiao:Personagem {nome: "Guardião das Florestas", descrição: "Um elfo sábio e corajoso, conhecido por sua habilidade de se comunicar com os animais e proteger a natureza"}),
# ...

# %%
local_bg = df_bg.iloc[0, 1]

# %%
print(local_bg)
# Out:
# No vasto continente de Altharia, onde a magia flui em cada fio de ar, e auras místicas pintam o céu, um grupo de aventureiros se reúne para enfrentar o perigo que ameaça o reino. Eles são liderados por Sirian, um guerreiro valente e honrado, cuja armadura reluz na luz do sol. Através de masmorras sombrias e cavernas profundas, eles desbravam os caminhos perigosos, buscando por tesouros escondidos, enfrentando monstros lendários e desvendando enigmas antigos.
#
# Entre os desafios encontrados por essa guilda brava e corajosa, destaca-se a Cidadela dos Sonhos, um local misterioso e encantado onde a realidade e os sonhos se entrelaçam. Esta fortaleza é guardada pelos Sussurros, seres etéreos cujas vozes ecoam entre as muralhas de pedra. Dizem as lendas que aqueles que adentram a Cidadela têm suas almas expostas, e apenas os mais puros de coração terão a chance de desvendar os segredos ocultos em seu interior.
#
# ...

# %%
background_graph = api_t0_16k.predict_messages([SystemMessage(content=prompt_system_cypher),
                                               HumanMessage(content=local_bg)]).content

# %%
#background_graph_bkp = background_graph
cypher_bg = cypher_bg_bkp

# %%
print(cypher_bg_bkp)
# Out:
# CREATE (altharia:Loc_assentamento {nome: "Altharia", descrição: "Um vasto continente onde a magia flui e auras místicas pintam o céu"}),
# (sirian:Personagem {nome: "Sirian", descrição: "Um guerreiro valente e honrado, líder do grupo de aventureiros"}),
# (cidadela:Construcao {nome: "Cidadela dos Sonhos", descrição: "Um local misterioso e encantado onde a realidade e os sonhos se entrelaçam"}),
# (sussurros:Personagem {nome: "Sussurros", descrição: "Seres etéreos cujas vozes ecoam entre as muralhas da Cidadela dos Sonhos"}),
# (floresta:Loc_assentamento {nome: "Floresta Proibida de Eldreth", descrição: "Uma floresta sombria habitada por criaturas fantásticas"}),
# (pedra:Objeto {nome: "Pedra da Eternidade", descrição: "Um artefato sagrado enterrado na Floresta Proibida de Eldreth"}),
# (anciao:Personagem {nome: "Ancião das Árvores", descrição: "Guardião da Floresta Proibida de Eldreth"}),
# ...

# %% [markdown]
# ### T2G do background expandido

# %%
sys_t2g_expand = """Você é um ajudante que:
Passo 1: Lê uma lista de entidades 
Passo 2: Lê uma lista de relacionamentos;
Passo 3: Lê um texto;
Passo 4: Lista entidades e relacionamentos que devem ser adicionados nas listas, a partir das informações contidas no texto.

As entidades presentes no texto podem ser classificadas os rótulos:
1. Loc_assentamento: Lugares físicos, como continentes, cidades, montanhas ou florestas;
2.  Construcao: Construções e formações naturais. Exemplos: casa, masmorra, caverna, castelo;
3. Veiculo: Meios de transporte. Exemplo: carro, navio, bicicleta.
4. Objeto: Itens tangíveis ou documentos. Exemplos: armas, roupas, cartas, livros.
5. Personagem: Indivíduos ou animais em papéis específicos. Exemplos: herói, vilão, guarda, animal de estimação.
6. Especie: Grupos biológicos ou culturais. Exemplos: elfos, humanos, cachorros.
7. Condicao: Estados físicos ou emocionais. Exemplos: doença, inspiração, tristeza.
8. Drama: Desafios ou tensões socioculturais. Exemplos: influência militar, relações de classe, problemas econômicos.
9. Organizacao: Grupos com propósitos comuns. Exemplos: igrejas, governos, seitas.
10. Titulo: Cargos, funções ou status. Exemplos: taberneiro, Rei, General.
11. Mito: Narrativas ou crenças. Exemplos: lendas sobre a origem do universo, mitos de monstros.

As entidades devem ter as propriedades "nome", "descrição". "descrição" é uma descrição detalhada com todas as informações referentes à entidade.

Os relacionamentos devem ser representados por trios de sujeito, predicado e objeto, onde o sujeito e o objeto são entidades mapeadas e o predicado pode ter os seguintes rótulos:
1. ESTA_EM: Representa localização ou uso.
2. RELACAO_POSITIVA: Denota uma interação ou vínculo interpessoal positivo.
3. RELACAO_NEGATIVA: Denota uma interação ou vínculo interpessoal negativo.
4. RELACAO_NEUTRA: Denota uma interação ou vínculo interpessoal neutro.
5. AFETADO_POR: Mostra entidades impactadas por condições ou conflitos.
6. MEMBRO_DE: Indica pertencimento a grupos, categorias ou organizações.
7. BASEADO_EM: Liga entidades a histórias, mitos, lendas ou influências culturais.
8. FAMILIAR: Representa laços de descendência ou ancestralidade.
9. PROPRIETARIO_DE: Denota posse direta.
9. SUCEDE: Representa o que vem depois em uma sequência temporal.
10. ANTECEDE: Representa o que vem antes em uma sequência temporal.

Garanta que o nome das entidades é único.
Garanta que todos os sujeitos e o objetos das relações também estão listados na lista de entidades."""

print(sys_t2g_expand)
# Out:
# Você é um programador profissional que lê um código Cypher e um texto, e atualiza o código com as informações contidas no texto.
#
# Todas as entidades presentes no texto devem ser representados como vértices (nodes).
# Os nodes podem ter somente os labels:
# 1. Loc_assentamento: Lugares físicos, como continentes, cidades, montanhas ou florestas;
# 2.  Construcao: Construções e formações naturais. Exemplos: casa, masmorra, caverna, castelo;
# 3. Veiculo: Meios de transporte. Exemplo: carro, navio, bicicleta.
# 4. Objeto: Itens tangíveis ou documentos. Exemplos: armas, roupas, cartas, livros.
# 5. Personagem: Indivíduos ou animais em papéis específicos. Exemplos: herói, vilão, guarda, animal de estimação.
# 6. Especie: Grupos biológicos ou culturais. Exemplos: elfos, humanos, cachorros.
# 7. Condicao: Estados físicos ou emocionais. Exemplos: doença, inspiração, tristeza.
# ...

# %%
exemplo_temp = """# Entidades e Relacionamentos:

Eldoria
   - Rótulo: Loc_assentamento
   - Descrição: Continente com vastas terras.

Cidade de Prata
   - Rótulo: Loc_assentamento
   - Descrição: A Cidade de Prata é um assentamento majestoso localizado no coração de Eldoria. Suas torres imponentes e ruas de paralelepípedos atraem pessoas de todas as partes do continente. É considerada uma joia no horizonte.

Masmorra das Sombras
   - Rótulo: Construcao
   - Descrição: A Masmorra das Sombras é um labirinto subterrâneo localizado nas profundezas da Cidade de Prata. É um local sombrio e perigoso, temido por todos, pois abriga criaturas malignas e tesouros ocultos.

Dragões de Ébano
   - Rótulo: Veiculo
   - Descrição: Os Dragões de Ébano são majestosas criaturas aladas, com escamas negras e olhos flamejantes. São utilizados como meio de transporte pelos aventureiros de Eldoria, sendo capazes de voar pelos céus e transportar os heróis em suas costas.

Espada da Luz
   - Rótulo: Objeto
   - Descrição: A Espada da Luz é uma arma lendária encontrada na Masmorra das Sombras. É capaz de banir as trevas e proteger os inocentes. Possui um poder místico e é muito cobiçada pelos aventureiros.

Pergaminhos da Sabedoria
   - Rótulo: Objeto
   - Descrição: Os Pergaminhos da Sabedoria são documentos encontrados na Masmorra das Sombras. Contêm conhecimentos ancestrais e segredos ocultos, sendo muito valiosos para os estudiosos e magos de Eldoria.

Guardião das Florestas
   - Rótulo: Personagem
   - Descrição: O Guardião das Florestas é um elfo sábio e corajoso. É conhecido por sua habilidade de se comunicar com os animais e proteger a natureza. Lidera a Ordem dos Guardiões, uma seita de guerreiros dedicados a combater as forças do mal.

Aurora
   - Rótulo: Personagem
   - Descrição: Aurora é um lobo branco e animal de estimação do Guardião das Florestas. Sempre fiel ao seu mestre, acompanha-o em suas aventuras por Eldoria.

Elfos
   - Rótulo: Especie
   - Descrição: Os elfos são uma raça de seres mágicos em Eldoria. São conhecidos por sua sabedoria e habilidades místicas. Possuem uma conexão especial com a natureza e são capazes de se comunicar com os animais.

Anões
   - Rótulo: Especie
   - Descrição: Os anões são uma raça de seres habilidosos em trabalhos manuais e na forja de armas. São conhecidos por sua resistência e força física. Possuem uma cultura única e são muito respeitados em Eldoria.

Humanos
    - Rótulo: Especie
    - Descrição: Os humanos são uma raça versátil e adaptável em Eldoria. São capazes de se adaptar a qualquer situação e possuem uma grande diversidade cultural. São considerados os mais numerosos entre as raças.

Praga das Sombras
    - Rótulo: Condicao
    - Descrição: A Praga das Sombras é uma doença misteriosa que afeta os habitantes de Eldoria. Torna as pessoas fracas e desesperançosas. A cura para essa condição está escondida em algum lugar do continente.

Conflito do Império das Chamas
	- Rótulo: Drama
	- Descrição: Uma organização poderosa e expansionista que ameaça a paz do continente.

Império das Chamas
    - Rótulo: Organizacao
    - Descrição: O Império das Chamas é uma organização militar poderosa e expansionista em Eldoria. Sua influência ameaça a paz do continente. Possui um exército bem treinado e busca dominar os recursos e o poder econômico.

Ordem dos Guardiões
    - Rótulo: Organizacao
    - Descrição: A Ordem dos Guardiões é uma seita de guerreiros liderada pelo Guardião das Florestas. Seu objetivo é proteger os inocentes e combater as forças do mal em Eldoria. São conhecidos por sua coragem e habilidades de combate.

Irmandade dos Sábios
    - Rótulo: Organizacao
    - Descrição: A Irmandade dos Sábios é uma organização de estudiosos e magos em Eldoria. Buscam desvendar os segredos da magia e preservar o conhecimento ancestral. São considerados os guardiões do conhecimento em Eldoria.

Elite Nobre
    - Rótulo: Organizacao
    - Descrição: Grupo de nobres que domina os recursos e o poder econômico.

Taberneiro
    - Rótulo: Titulo
    - Descrição: O taberneiro é responsável por fornecer abrigo e comida aos aventureiros em Eldoria. É uma profissão importante, pois os aventureiros cansados precisam de um local para descansar e se recuperar.

Rei/Rainha
    - Rótulo: Titulo
    - Descrição: O Rei/Rainha é o governante de um reino em Eldoria. São responsáveis por tomar decisões importantes e governar com sabedoria e justiça. Possuem um grande poder político e são respeitados por seus súditos.

General
    - Rótulo: Titulo
    - Descrição: O General é um título dado ao líder de um exército em Eldoria. São responsáveis por liderar as tropas na defesa do continente. Possuem habilidades estratégicas e são respeitados por sua coragem e liderança.

Lenda do Dragão Primordial
    - Rótulo: Mito
    - Descrição: O Dragão Primordial é uma criatura ancestral em Eldoria. Segundo a lenda, teria criado o mundo com seu sopro de fogo. É considerado uma figura divina e possui um papel importante nas crenças e mitos do continente.

Cidade de Prata ESTA_EM Eldoria
Masmorra das Sombras ESTA_EM Cidade de Prata
Dragões de Ébano ESTA_EM Eldoria
Espada da Luz ESTA_EM Masmorra das Sombras
Pergaminhos da Sabedoria ESTA_EM Masmorra das Sombras
Guardião das Florestas MEMBRO_DE Ordem dos Guardiões
Guardião das Florestas PROPRIETARIO_DE Aurora
Eldoria AFETADO_POR Praga das Sombras
Eldoria AFETADO_POR Conflito do Império das Chamas
Império das Chamas BASEADO_EM Conflito do Império das Chamas
Taberneiro ESTA_EM Cidade de Prata
Rei/Rainha ESTA_EM Eldoria
General ESTA_EM Eldoria
Eldoria BASEADO_EM Lenda do Dragão Primordial
Ordem dos Guardiões RELACAO_POSITIVA Cidade de Prata
Irmandade dos Sábios RELACAO_POSITIVA Cidade de Prata

# Texto:

O Império das Chamas era uma potência militar em Eldoria, cuja sede estava na Fortaleza do Fogo, uma imponente fortaleza situada em uma ilha vulcânica. Sob o comando do Imperador Akeldar, o império buscava expandir seu território e impor sua vontade sobre os demais reinos do continente.

As motivações do Império das Chamas eram diversas. Primeiramente, eles acreditavam na supremacia do seu povo e na ideia de que deveriam unificar Eldoria sob seu governo para trazer ordem e estabilidade. Além disso, o império via outras nações como fontes de recursos que poderiam ser explorados para seu benefício econômico e militar.

A expansão territorial do Império das Chamas era implacável. Suas legiões avançavam conquistando um reino após o outro, com suas armaduras avermelhadas e estandartes flamejantes aterrorizando as populações oponentes. Fortalezas, cidades e vilas eram tomadas pelo exército do império, e a resistência era ferozmente reprimida.

Essa expansão militar do Império das Chamas causava um grande impacto nas relações entre os reinos de Eldoria. Os reinos independentes eram forçados a tomar uma posição diante da ameaça iminente. Alguns optavam por se render e se submeter ao Império das Chamas, buscando garantir a segurança de seus povos e evitar a destruição total. Outros, no entanto, resistiam bravamente, unindo suas forças em alianças e liderando a defesa contra as tropas invasoras.

Essa polarização criava uma atmosfera de tensão e incerteza entre os reinos. As alianças eram formadas e desfeitas de acordo com as circunstâncias e interesses mútuos. Estratégias de guerrilha, emboscadas e furtividade eram empregadas pelos reinos independentes para tentar resistir ao avanço implacável do Império das Chamas.

As relações comerciais também eram afetadas pela influência do Império das Chamas. O império buscava controlar as rotas comerciais e estabelecer tributos e taxas sobre as mercadorias que passavam por seus domínios. Os reinos independentes, por sua vez, buscavam encontrar rotas alternativas e estabelecer acordos comerciais entre si para contornar as imposições do império.

Além disso, a presença do Império das Chamas também abalava o equilíbrio de poder entre as diferentes facções de Eldoria. Os reinos que se submetiam ao império perdiam sua autonomia e viam seus recursos e governança sendo controlados pelo Imperador Akeldar. Isso gerava descontentamento e resistência interna, com grupos rebeldes surgindo para lutar contra o domínio imperial.

O Império das Chamas também exercia influência sobre a prática religiosa em Eldoria. O império promovia a adoração ao deus do fogo, um ser ardente e impiedoso que exigia sacrifícios e devoção dos seus seguidores. Templos dedicados a essa divindade eram erguidos nas cidades conquistadas pelo Império das Chamas, e cultos e rituais passaram a fazer parte do cotidiano das pessoas.

Em resumo, a influência do Império das Chamas em Eldoria era marcada por sua expansão territorial e militar implacável, suas motivações de poder e controle, e o impacto nas relações entre os reinos do continente. Essa presença imperial gerava tensões, resistência e mudanças significativas na política, economia e cultura de Eldoria."""

# %%
exemplo_temp2 = """Reinos independentes
   - Rótulo: Loc_assentamento
   - Descrição: Diversos reinos independentes em Eldoria.

Fortaleza do Fogo
   - Rótulo: Construcao
   - Descrição: A Fortaleza do Fogo é uma imponente fortaleza situada em uma ilha vulcânica. É a sede do Império das Chamas e serve como base para suas operações militares.

Imperador Akeldar
   - Rótulo: Personagem
   - Descrição: O Imperador Akeldar é o líder do Império das Chamas. Ele comanda as legiões do império e busca expandir seu território e impor sua vontade sobre os demais reinos de Eldoria.

Resistência contra o Império das Chamas
   - Rótulo: Drama
   - Descrição: Forças que se opõem ao Império das Chamas.

Relações comerciais em Eldoria
   - Rótulo: Drama
   - Descrição: Trocas comerciais entre os reinos de Eldoria.

Influência religiosa do Império das Chamas
   - Rótulo: Drama
   - Descrição: Adoração ao deus do fogo promovida pelo Império das Chamas.

Império das Chamas ESTA_EM Fortaleza do Fogo
Imperador Akeldar MEMBRO_DE Império das Chamas

Império das Chamas RELACAO_NEGATIVA Reinos independentes
Reinos independentes RELACAO_NEGATIVA Império das Chamas
Reinos independentes RELACAO_POSITIVA Alianças
Reinos independentes RELACAO_POSITIVA Grupos rebeldes
Império das Chamas AFETADO_POR Resistência contra o Império das Chamas
Império das Chamas BASEADO_EM Influência religiosa do Império das Chamas

Reinos independentes AFETADO_POR Resistência contra o Império das Chamas
Reinos independentes AFETADO_POR Relações comerciais em Eldoria
Reinos independentes AFETADO_POR Influência religiosa do Império das Chamas"""

# %%
print(df_bg.iloc[5, 1])
# Out:
# Erguendo-se majestosa em meio à paisagem de Altharia, a imponente Torre dos Magos domina o horizonte, suas paredes de pedra negra e janelas arqueadas brilham sob o brilho do sol. Localizada em uma das regiões mais remotas do continente, rodeada por florestas densas, a Torre dos Magos serve como o centro de estudos e práticas mágicas em todo o reino.
#
# Os corredores labirínticos da torre ecoam com murmúrios de encantamentos antigos, enquanto os estudiosos se dedicam a decifrar os segredos da magia e a buscar o conhecimento arcano. Cada andar da torre abriga uma especialidade, seja a magia elemental, a necromancia, a transmutação ou qualquer outro ramo mágico. Os magos se reúnem em seus aposentos, compartilhando seus conhecimentos em incansáveis discussões e debates acalorados.
#
# ...

# %%
t2g_exp_template = """Identifique as entidades e relações novas contidas no texto, atualize o código e retorne o código atualizado completo. Garanta que o código tenha apenas nós ou relações únicas.
<código> {code} <\código>
<texto> {text} <\texto>"""
t2g_exp_prompt = HumanMessagePromptTemplate.from_template(t2g_exp_template)
chat_prompt = ChatPromptTemplate.from_messages([SystemMessage(content=sys_t2g_expand),
                                                t2g_exp_prompt])
chain = LLMChain(llm=chat_t0_16k, prompt=chat_prompt)

for local_expanded in df_bg.iloc[1:].content:
    background_graph = chain.run(code=background_graph, text=local_expanded)

# %%
print(background_graph)
# Out:
# Entidades novas:
# - Loc_assentamento: Altharia
# - Construcao: fortalezas, castelos, salões das montanhas, cidades subterrâneas
# - Veiculo: carruagens mágicas
# - Objeto: cristais arcanos, esferas de invocação, amuletos de controle mental, martelos, bigornas
# - Personagem: guerreiros, elfos, anões, humanos, gnomos, hobbits
# - Especie: raças (elfos, anões, humanos, gnomos, hobbits)
# - Drama: conflitos e tensões entre facções
# - Organizacao: festivais
# - Titulo: artistas
#
# Relações novas:
# - ESTA_EM: Altharia está localizado no reino
# - ESTA_EM: fortalezas e castelos estão localizados em Altharia
# - ESTA_EM: salões das montanhas estão localizados em Altharia
# - ESTA_EM: cidades subterrâneas estão localizadas em Altharia
# - ESTA_EM: carruagens mágicas são usadas para transporte entre cidades distantes
# - ESTA_EM: cristais arcanos são usados para alimentar as carruagens mágicas
# - ESTA_EM: martelos e bigornas são usados para forjar armas e instrumentos de percussão
# ...

# %%
with open(r".\files\cypher_all.txt", "w") as file:
    file.write(cypher_all)

# %%
prompt_resume_query = """Dada a seguinte query Cypher do Neo4j:


CREATE (cidadela:Construcao {nome: "Cidadela dos Sonhos", descrição: "Uma estrutura majestosa nos confins de Altharia, envolta em névoa mágica e mistério"}),
(entidades:Loc_assentamento {nome: "Entidades Celestiais", descrição: "Serem divinos que governam os sonhos"}),
(reinos:Loc_assentamento {nome: "Reinos Humanos e Élficos", descrição: "Reinos que se fundiram"}),
(pacto:Relacao {nome: "Pacto entre Monarcas", descrição: "Pacto formado entre os monarcas das raças humanas e élficas para proteger a fronteira entre o plano dos sonhos e a realidade"}),
(mestre:Personagem {nome: "Mestre dos Sonhos", descrição: "Ser místico que conta as histórias do passado e desafia os aventureiros"}),
(biblioteca:Construcao {nome: "Biblioteca dos Sonhadores", descrição: "Uma imensa sala com estantes repletas de livros antigos e empoeirados"}),
(chave:Objeto {nome: "Chave do Mistério", descrição: "Uma chave preciosa que desvenda o mistério mais profundo da Cidadela"}),
(guardioes:Personagem {nome: "Guardiões dos Sonhos", descrição: "Criaturas místicas feitas de pura energia mágica, nascidas da união dos sonhos de almas adormecidas"}),
(lendas:Mito {nome: "Lenda da Cidadela dos Sonhos", descrição: "Lenda repleta de questionamentos e reflexões sobre a natureza da realidade, sonhos e desejos"}),
(aventureiros:Personagem {nome: "Aventureiros", descrição: "Indivíduos que se aventuram na Cidadela dos Sonhos em busca de conhecimento e sabedoria"}),
(dons:Objeto {nome: "Dons e Conhecimentos", descrição: "Recompensas concedidas aos aventureiros dignos que desvendam os segredos da Cidadela"})

CREATE (cidadela)-[:ESTA_EM]->(altharia),
(entidades)-[:ESTA_EM]->(cidadela),
(reinos)-[:ESTA_EM]->(cidadela),
(pacto)-[:ESTA_EM]->(cidadela),
(mestre)-[:ESTA_EM]->(cidadela),
(biblioteca)-[:ESTA_EM]->(cidadela),
(chave)-[:ESTA_EM]->(biblioteca),
(guardioes)-[:ESTA_EM]->(cidadela),
(lendas)-[:BASEADO_EM]->(cidadela),
(aventureiros)-[:ESTA_EM]->(cidadela),
(dons)-[:ESTA_EM]->(cidadela)
CREATE (floresta:Loc_assentamento {nome: "Floresta Proibida de Eldreth", descrição: "Um lugar repleto de mistérios e perigos, onde a natureza selvagem e a magia antiga se unem"}),
(elfos_selvagens:Especie {nome: "Elfos Selvagens", descrição: "Seres esguios e ágeis que vivem em harmonia com a natureza, dotados de grande sabedoria e habilidades arcanas"}),
(licantropos:Especie {nome: "Licantropos", descrição: "Humanos amaldiçoados que se transformam em bestas feroces na luz da lua cheia"}),
(driades:Especie {nome: "Dríades", descrição: "Espíritos guardiões das árvores, dotadas de uma beleza transcendente e capazes de se fundir com a vegetação ao seu redor"}),
(anciao:Construcao {nome: "Ancião das Árvores", descrição: "Uma árvore ancestral reverenciada como a personificação da sabedoria e da natureza em sua forma mais pura"}),
(pedra:Objeto {nome: "Pedra da Eternidade", descrição: "Um artefato sagrado enterrado nas raízes do Ancião das Árvores, envolto em mistério e poder"}),
(floresta)-[:ESTA_EM]->(eldoria),
(elfos_selvagens)-[:ESTA_EM]->(floresta),
(licantropos)-[:ESTA_EM]->(floresta),
(driades)-[:ESTA_EM]->(floresta),
(anciao)-[:ESTA_EM]->(floresta),
(pedra)-[:ESTA_EM]->(anciao),
(elfos_selvagens)-[:RELACAO_POSITIVA]->(floresta),
(licantropos)-[:RELACAO_NEGATIVA]->(floresta),
(driades)-[:RELACAO_POSITIVA]->(floresta),
(floresta)-[:BASEADO_EM]->(floresta),
(anciao)-[:BASEADO_EM]->(floresta),
(pedra)-[:BASEADO_EM]->(floresta)
CREATE (altharia:Loc_assentamento {nome: "Altharia", descrição: "Um reino ameaçado pelo mal antigo"}),
(lorde_sombras:Personagem {nome: "Lorde das Sombras", descrição: "Um líder temido que comanda o exército do mal"}),
(altairon:Personagem {nome: "Altairon", descrição: "Arauto da destruição e líder do exército do Lorde das Sombras"}),
(corvus:Personagem {nome: "Corvus", descrição: "Um paladino cuja armadura brilha com a luz da esperança"}),
(lyra:Personagem {nome: "Lyra", descrição: "Uma bruxa poderosa que invoca o fogo dos espíritos ancestrais"}),
(athanar:Personagem {nome: "Athanar", descrição: "Um elfo arqueiro habilidoso, cujas flechas perfuram as defesas do inimigo"}),
(arlene:Personagem {nome: "Arlene", descrição: "Uma guerreira destemida destinada a enfrentar Altairon no duelo final"}),
(erevan:Personagem {nome: "Erevan", descrição: "Um elfo sombrio que se tornou vigilante, protegendo os mais fracos"}),
(bruna:Personagem {nome: "Bruna", descrição: "Uma clériga dedicada aos deuses da cura"}),
(zephyr:Personagem {nome: "Zephyr", descrição: "Um ladino astuto e talentoso, capaz de se infiltrar nas linhas inimigas"}),
(destinados:Organizacao {nome: "Os Destinados", descrição: "Um grupo de guerreiros lendários reunidos por Arlene"}),
(altharia)-[:ESTA_EM]->(altharia),
(lorde_sombras)-[:ESTA_EM]->(altharia),
(altairon)-[:ESTA_EM]->(altharia),
(corvus)-[:ESTA_EM]->(altharia),
(lyra)-[:ESTA_EM]->(altharia),
(athanar)-[:ESTA_EM]->(altharia),
(arlene)-[:ESTA_EM]->(altharia),
(erevan)-[:ESTA_EM]->(altharia),
(bruna)-[:ESTA_EM]->(altharia),
(zephyr)-[:ESTA_EM]->(altharia),
(corvus)-[:RELACAO_POSITIVA]->(lyra),
(corvus)-[:RELACAO_POSITIVA]->(athanar),
(arlene)-[:RELACAO_POSITIVA]->(erevan),
(arlene)-[:RELACAO_POSITIVA]->(bruna),
(arlene)-[:RELACAO_POSITIVA]->(zephyr),
(arlene)-[:MEMBRO_DE]->(destinados),
(altharia)-[:AFETADO_POR]->(lorde_sombras),
(altharia)-[:AFETADO_POR]->(altairon),
(altharia)-[:RELACAO_NEGATIVA]->(lorde_sombras),
(altharia)-[:RELACAO_NEGATIVA]->(altairon),
(corvus)-[:RELACAO_POSITIVA]->(altharia),
(lyra)-[:RELACAO_POSITIVA]->(altharia),
(athanar)-[:RELACAO_POSITIVA]->(altharia),
(arlene)-[:RELACAO_POSITIVA]->(altharia),
(erevan)-[:RELACAO_POSITIVA]->(altharia),
(bruna)-[:RELACAO_POSITIVA]->(altharia),
(zephyr)-[:RELACAO_POSITIVA]->(altharia)
CREATE (altharia:Loc_assentamento {nome: "Altharia", descrição: "Reino onde os jogos políticos e as intrigas entre os líderes moldam o destino"}),
(sombrelanda:Loc_assentamento {nome: "Sombrelanda", descrição: "Majestosa cidade que é a capital de Altharia"}),
(palacio:Construcao {nome: "Palácio Real", descrição: "Centro das intrigas políticas em Sombrelanda"}),
(rei:Personagem {nome: "Rei Valerian", descrição: "Um governante astuto e calculista que manipula as alianças e mantém os laços com outras terras"}),
(casa_espinhos:FAMILIAR {nome: "Casa de Espinhos", descrição: "Uma família de nobres ambiciosos que conspira para minar o rei Valerian e tomar o trono"}),
(lady_isabella:Personagem {nome: "Lady Isabella", descrição: "Líder da Casa de Espinhos, uma mulher de beleza enigmática e astúcia implacável"}),
(luminara:Loc_assentamento {nome: "Luminara", descrição: "Cidade dos elfos"}),
(rainha:Personagem {nome: "Rainha Seraphina", descrição: "Uma líder justa e sábia que governa Luminara"}),
(ordem_magos:Organizacao {nome: "Ordem dos Magos", descrição: "Uma organização poderosa e enigmática que exerce grande influência nos assuntos do reino"}),
(liga_rebeldes:Organizacao {nome: "Liga dos Rebeldes", descrição: "Um grupo de insurgentes ousados que luta nas sombras para derrubar os tiranos e trazer igualdade ao reino"}),
(libertador:Personagem {nome: "O Libertador", descrição: "Misterioso líder da Liga dos Rebeldes"}),
(altharia)-[:ESTA_EM]->(sombrelanda),
(sombrelanda)-[:ESTA_EM]->(altharia),
(palacio)-[:ESTA_EM]->(sombrelanda),
(rei)-[:ESTA_EM]->(palacio),
(casa_espinhos)-[:ESTA_EM]->(sombrelanda),
(lady_isabella)-[:ESTA_EM]->(casa_espinhos),
(luminara)-[:ESTA_EM]->(altharia),
(rainha)-[:ESTA_EM]->(luminara),
(ordem_magos)-[:ESTA_EM]->(altharia),
(liga_rebeldes)-[:ESTA_EM]->(altharia),
(libertador)-[:ESTA_EM]->(liga_rebeldes),
(rei)-[:RELACAO_POSITIVA]->(casa_espinhos),
(rei)-[:RELACAO_POSITIVA]->(ordem_magos),
(rainha)-[:RELACAO_POSITIVA]->(ordem_magos),
(rainha)-[:RELACAO_POSITIVA]->(liga_rebeldes),
(casa_espinhos)-[:RELACAO_NEGATIVA]->(rei),
(lady_isabella)-[:RELACAO_NEGATIVA]->(rei),
(rainha)-[:RELACAO_NEGATIVA]->(casa_espinhos),
(rainha)-[:RELACAO_NEGATIVA]->(luminara),
(ordem_magos)-[:RELACAO_POSITIVA]->(rei),
(ordem_magos)-[:RELACAO_POSITIVA]->(rainha),
(liga_rebeldes)-[:RELACAO_POSITIVA]->(rainha),
(liga_rebeldes)-[:RELACAO_NEGATIVA]->(ordem_magos)
CREATE (altharia:Loc_assentamento {nome: "Altharia", descrição: "Continente com vastas terras"}),
(torre:Construcao {nome: "Torre dos Magos", descrição: "Uma imponente torre de pedra negra, centro de estudos e práticas mágicas"}),
(florestas:Loc_assentamento {nome: "Florestas Densas", descrição: "Região remota do continente, rodeada por florestas densas"}),
(magos:Organizacao {nome: "Magos", descrição: "Estudiosos e praticantes de magia"}),
(magia:Objeto {nome: "Conhecimento Arcano", descrição: "Segredos e práticas mágicas"}),
(andares:Construcao {nome: "Andares da Torre", descrição: "Cada andar da torre abriga uma especialidade mágica"}),
(estudiosos:Personagem {nome: "Estudiosos", descrição: "Magos dedicados a decifrar os segredos da magia e buscar o conhecimento arcano"}),
(faccoes:Organizacao {nome: "Fações Rivais", descrição: "Grupos de estudiosos com rivalidades intensas"}),
(duelos:Objeto {nome: "Duelos Mágicos", descrição: "Competições de prestígio e reputação entre os magos"}),
(camaras:Construcao {nome: "Câmaras Secretas", descrição: "Salas proibidas com mistérios antigos e ocultos"}),
(livros:Objeto {nome: "Livros Mágicos", descrição: "Livros com conhecimentos mágicos e páginas feitas de pele de dragão"}),
(cristais:Objeto {nome: "Cristais Místicos", descrição: "Cristais contendo poderes inimagináveis"}),
(artefatos:Objeto {nome: "Artefatos Lendários", descrição: "Objetos que carregam a história do mundo"}),
(praticas:Construcao {nome: "Práticas Ilegais", descrição: "Práticas ilegais e proibidas ocorrem nas sombras da torre"}),
(aprendizes:Personagem {nome: "Aprendizes", descrição: "Alunos novatos em busca de serem aceitos como aprendizes pelos mestres renomados"}),
(testes:Objeto {nome: "Testes Rigorosos", descrição: "Provas exaustivas para provar a aptidão para controlar os poderes arcanos"}),
(ordem:Organizacao {nome: "Ordem dos Magos", descrição: "Ordem seleta de magos que oferecem tutela e orientação"}),
(guardioes:Personagem {nome: "Guardiães Esquecidos", descrição: "Magos lendários do passado, venerados pelos estudiosos"}),
(aventureiros:Personagem {nome: "Aventureiros", descrição: "Indivíduos em busca de conhecimento arcano e desvendar mistérios"}),
(desafios:Construcao {nome: "Desafios Internos e Externos", descrição: "Desafios que os aventureiros enfrentarão em sua busca pelo conhecimento arcano"}),
(poder:Objeto {nome: "Poder da Magia", descrição: "A magia oferece poder e maravilhas, mas também o potencial para a ruína"}),
(magia)-[:ESTA_EM]->(torre),
(torre)-[:ESTA_EM]->(altharia),
(torre)-[:ESTA_EM]->(florestas),
(estudiosos)-[:ESTA_EM]->(torre),
(andares)-[:ESTA_EM]->(torre),
(faccoes)-[:ESTA_EM]->(torre),
(duelos)-[:ESTA_EM]->(torre),
(camaras)-[:ESTA_EM]->(torre),
(livros)-[:ESTA_EM]->(camaras),
(cristais)-[:ESTA_EM]->(camaras),
(artefatos)-[:ESTA_EM]->(camaras),
(praticas)-[:ESTA_EM]->(torre),
(aprendizes)-[:ESTA_EM]->(torre),
(testes)-[:ESTA_EM]->(torre),
(ordem)-[:ESTA_EM]->(torre),
(guardioes)-[:ESTA_EM]->(torre),
(aventureiros)-[:ESTA_EM]->(torre),
(desafios)-[:ESTA_EM]->(torre),
(poder)-[:ESTA_EM]->(torre)
CREATE (altharia:Loc_assentamento {nome: "Altharia", descrição: "Um mundo repleto de diversidade, onde diversas raças coexistem"}),
(elfos:Especie {nome: "Elfos", descrição: "Raça conhecida por sua graciosa beleza e longevidade, com forte relação com a natureza"}),
(anoes:Especie {nome: "Anões", descrição: "Raça conhecida por sua força e habilidade nas artes da guerra e da metalurgia"}),
(humanos:Especie {nome: "Humanos", descrição: "Raça versátil e adaptável, formando a base da sociedade em Altharia"}),
(lobisomens:Especie {nome: "Lobisomens", descrição: "Criaturas que combinam a força dos lobos com a inteligência humana"}),
(centauros:Especie {nome: "Centauros", descrição: "Criaturas metade humanas e metade cavalos"}),
(dragoes:Especie {nome: "Dragões", descrição: "Criaturas lendárias com culturas e tradições próprias"}),
(elfos)-[:ESTA_EM]->(altharia),
(anoes)-[:ESTA_EM]->(altharia),
(humanos)-[:ESTA_EM]->(altharia),
(lobisomens)-[:ESTA_EM]->(altharia),
(centauros)-[:ESTA_EM]->(altharia),
(dragoes)-[:ESTA_EM]->(altharia),
(elfos)-[:RELACAO_POSITIVA]->(natureza),
(elfos)-[:RELACAO_POSITIVA]->(sabedoria),
(elfos)-[:RELACAO_POSITIVA]->(magia),
(anoes)-[:RELACAO_POSITIVA]->(forca),
(anoes)-[:RELACAO_POSITIVA]->(metalurgia),
(anoes)-[:RELACAO_POSITIVA]->(honra),
(humanos)-[:RELACAO_POSITIVA]->(versatilidade),
(humanos)-[:RELACAO_POSITIVA]->(criatividade),
(humanos)-[:RELACAO_POSITIVA]->(poder),
(lobisomens)-[:RELACAO_POSITIVA]->(forca),
(lobisomens)-[:RELACAO_POSITIVA]->(inteligencia),
(lobisomens)-[:RELACAO_POSITIVA]->(matilha),
(centauros)-[:RELACAO_POSITIVA]->(honra),
(centauros)-[:RELACAO_POSITIVA]->(sabedoria),
(centauros)-[:RELACAO_POSITIVA]->(natureza),
(elfos)-[:MEMBRO_DE]->(sociedade),
(anoes)-[:MEMBRO_DE]->(sociedade),
(humanos)-[:MEMBRO_DE]->(sociedade),
(lobisomens)-[:MEMBRO_DE]->(sociedade),
(centauros)-[:MEMBRO_DE]->(sociedade),
(dragoes)-[:MEMBRO_DE]->(sociedade),
(elfos)-[:RELACAO_POSITIVA]->(sociedade),
(anoes)-[:RELACAO_POSITIVA]->(sociedade),
(humanos)-[:RELACAO_POSITIVA]->(sociedade),
(lobisomens)-[:RELACAO_POSITIVA]->(sociedade),
(centauros)-[:RELACAO_POSITIVA]->(sociedade),
(dragoes)-[:RELACAO_POSITIVA]->(sociedade),
(elfos)-[:RELACAO_POSITIVA]->(relacoes_interpessoais),
(anoes)-[:RELACAO_POSITIVA]->(relacoes_interpessoais),
(humanos)-[:RELACAO_POSITIVA]->(relacoes_interpessoais),
(lobisomens)-[:RELACAO_POSITIVA]->(relacoes_interpessoais),
(centauros)-[:RELACAO_POSITIVA]->(relacoes_interpessoais),
(dragoes)-[:RELACAO_POSITIVA]->(relacoes_interpessoais),
(elfos)-[:BASEADO_EM]->(cultura),
(anoes)-[:BASEADO_EM]->(cultura),
(humanos)-[:BASEADO_EM]->(cultura),
(lobisomens)-[:BASEADO_EM]->(cultura),
(centauros)-[:BASEADO_EM]->(cultura),
(dragoes)-[:BASEADO_EM]->(cultura),
(elfos)-[:BASEADO_EM]->(hierarquia),
(anoes)-[:BASEADO_EM]->(hierarquia),
(humanos)-[:BASEADO_EM]->(hierarquia),
(lobisomens)-[:BASEADO_EM]->(hierarquia),
(centauros)-[:BASEADO_EM]->(hierarquia),
(dragoes)-[:BASEADO_EM]->(hierarquia),
(elfos)-[:BASEADO_EM]->(meritocracia),
(anoes)-[:BASEADO_EM]->(meritocracia),
(humanos)-[:BASEADO_EM]->(meritocracia),
(lobisomens)-[:BASEADO_EM]->(meritocracia),
(centauros)-[:BASEADO_EM]->(meritocracia),
(dragoes)-[:BASEADO_EM]->(meritocracia),
(elfos)-[:BASEADO_EM]->(sabedoria),
(anoes)-[:BASEADO_EM]->(honra),
(humanos)-[:BASEADO_EM]->(poder),
(lobisomens)-[:BASEADO_EM]->(forca),
(centauros)-[:BASEADO_EM]->(honra),
(dragoes)-[:BASEADO_EM]->(poder),
(elfos)-[:BASEADO_EM]->(magia),
(anoes)-[:BASEADO_EM]->(metalurgia),
(humanos)-[:BASEADO_EM]->(criatividade),
(lobisomens)-[:BASEADO_EM]->(inteligencia),
(centauros)-[:BASEADO_EM]->(sabedoria),
(dragoes)-[:BASEADO_EM]->(cultura),
(elfos)-[:BASEADO_EM]->(arte_arcanas),
(anoes)-[:BASEADO_EM]->(guerra),
(humanos)-[:BASEADO_EM]->(governanca),
(lobisomens)-[:BASEADO_EM]->(matilha),
(centauros)-[:BASEADO_EM]->(natureza),
(dragoes)-[:BASEADO_EM]->(cultura),
(elfos)-[:RELACAO_POSITIVA]->(diversidade),
(anoes)-[:RELACAO_POSITIVA]->(diversidade),
(humanos)-[:RELACAO_POSITIVA]->(diversidade),
(lobisomens)-[:RELACAO_POSITIVA]->(diversidade),
(centauros)-[:RELACAO_POSITIVA]->(diversidade),
(dragoes)-[:RELACAO_POSITIVA]->(diversidade),
(elfos)-[:RELACAO_POSITIVA]->(inclusao),
(anoes)-[:RELACAO_POSITIVA]->(inclusao),
(humanos)-[:RELACAO_POSITIVA]->(inclusao),
(lobisomens)-[:RELACAO_POSITIVA]->(inclusao),
(centauros)-[:RELACAO_POSITIVA]->(inclusao),
(dragoes)-[:RELACAO_POSITIVA]->(inclusao),
(elfos)-[:RELACAO_POSITIVA]->(respeito_mutuo),
(anoes)-[:RELACAO_POSITIVA]->(respeito_mutuo),
(humanos)-[:RELACAO_POSITIVA]->(respeito_mutuo),
(lobisomens)-[:RELACAO_POSITIVA]->(respeito_mutuo),
(centauros)-[:RELACAO_POSITIVA]->(respeito_mutuo),
(dragoes)-[:RELACAO_POSITIVA]->(respeito_mutuo)
CREATE (altharia:Loc_assentamento {nome: "Altharia", descrição: "Continente com diversas raças e culturas"}),
(fa_luz:Organizacao {nome: "Fé da Luz", descrição: "Religião que venera a deusa Seraphia, a Senhora da Esperança e da Iluminação"}),
(seraphia:Personagem {nome: "Seraphia", descrição: "Deusa venerada pela Fé da Luz, símbolo da pureza e da bondade"}),
(clerigos:Titulo {nome: "Clérigos da Fé da Luz", descrição: "Seguidores habilidosos em magias curativas"}),
(ordem_sombria:Organizacao {nome: "Ordem do Crepúsculo Shadow", descrição: "Seita que adora deuses sombrios e misteriosos"}),
(tribos_antigos:Organizacao {nome: "Tribos dos Antigos", descrição: "Adoram os espíritos dos elementos da natureza"}),
(quimeristas:Organizacao {nome: "Quimeristas", descrição: "Reverenciam os dragões como seres divinos"}),
(ordem_transcendentais:Organizacao {nome: "Ordem dos Transcendentais", descrição: "Buscam a transcendência espiritual através de meditação e disciplina mental"}),
(clerigos)-[:MEMBRO_DE]->(fa_luz),
(ordem_sombria)-[:MEMBRO_DE]->(altharia),
(tribos_antigos)-[:MEMBRO_DE]->(altharia),
(quimeristas)-[:MEMBRO_DE]->(altharia),
(ordem_transcendentais)-[:MEMBRO_DE]->(altharia),
(clerigos)-[:RELACAO_POSITIVA]->(altharia),
(ordem_sombria)-[:RELACAO_NEGATIVA]->(altharia),
(tribos_antigos)-[:RELACAO_POSITIVA]->(altharia),
(quimeristas)-[:RELACAO_POSITIVA]->(altharia),
(ordem_transcendentais)-[:RELACAO_POSITIVA]->(altharia),
(clerigos)-[:BASEADO_EM]->(fa_luz),
(ordem_sombria)-[:BASEADO_EM]->(altharia),
(tribos_antigos)-[:BASEADO_EM]->(altharia),
(quimeristas)-[:BASEADO_EM]->(altharia),
(ordem_transcendentais)-[:BASEADO_EM]->(altharia),
(clerigos)-[:RELACAO_POSITIVA]->(altharia),
(ordem_sombria)-[:RELACAO_NEGATIVA]->(altharia),
(tribos_antigos)-[:RELACAO_POSITIVA]->(altharia),
(quimeristas)-[:RELACAO_POSITIVA]->(altharia),
(ordem_transcendentais)-[:RELACAO_POSITIVA]->(altharia)
CREATE (altharia:Loc_assentamento {nome: "Altharia", descrição: "Mundo criado pelos deuses primordiais Aventus e Elyra"}),
(aventus:Personagem {nome: "Aventus", descrição: "Deus primordial, Senhor da Luz, traz a criação e o poder do sol"}),
(elyra:Personagem {nome: "Elyra", descrição: "Deusa primordial, Senhora das Sombras, traz a magia e a escuridão"}),
(antigos:Especie {nome: "Antigos", descrição: "Criaturas divinas com sabedoria ancestral e habilidades transcendentes"}),
(rios:Construcao {nome: "Antigo dos Rios", descrição: "Antigo que representa a faceta dos rios"}),
(florestas:Construcao {nome: "Antigo das Florestas", descrição: "Antigo que representa a faceta das florestas"}),
(tempestades:Construcao {nome: "Antigo das Tempestades", descrição: "Antigo que representa a faceta das tempestades"}),
(elfos:Especie {nome: "Elfos", descrição: "Raça descendente direta dos Antigos, conhecidos por sua graça e sabedoria"}),
(anoes:Especie {nome: "Anões", descrição: "Raça forte e resistente, com tradição de cidades subterrâneas"}),
(halflings:Especie {nome: "Halflings", descrição: "Raça ágil e astuta, com história de luta pela proteção de suas terras férteis"}),
(dragoes:Especie {nome: "Dragões", descrição: "Seres ancestrais com conexão profunda com a magia"}),
(civilizacoes:Construcao {nome: "Civilizações Perdidas", descrição: "Reinos distantes tocados pelo caos"}),
(elfos)-[:ANTECEDE]->(altharia),
(anoes)-[:ANTECEDE]->(altharia),
(halflings)-[:ANTECEDE]->(altharia),
(dragoes)-[:ANTECEDE]->(altharia),
(civilizacoes)-[:ANTECEDE]->(altharia),
(aventus)-[:BASEADO_EM]->(altharia),
(elyra)-[:BASEADO_EM]->(altharia),
(antigos)-[:BASEADO_EM]->(altharia),
(rios)-[:BASEADO_EM]->(altharia),
(florestas)-[:BASEADO_EM]->(altharia),
(tempestades)-[:BASEADO_EM]->(altharia),
(elfos)-[:RELACAO_POSITIVA]->(altharia),
(elfos)-[:RELACAO_POSITIVA]->(rios),
(elfos)-[:RELACAO_POSITIVA]->(florestas),
(elfos)-[:RELACAO_POSITIVA]->(tempestades),
(elfos)-[:RELACAO_POSITIVA]->(antigos),
(elfos)-[:RELACAO_POSITIVA]->(aventus),
(anoes)-[:RELACAO_POSITIVA]->(altharia),
(anoes)-[:RELACAO_POSITIVA]->(rios),
(anoes)-[:RELACAO_POSITIVA]->(florestas),
(anoes)-[:RELACAO_POSITIVA]->(tempestades),
(anoes)-[:RELACAO_POSITIVA]->(antigos),
(halflings)-[:RELACAO_POSITIVA]->(altharia),
(halflings)-[:RELACAO_POSITIVA]->(rios),
(halflings)-[:RELACAO_POSITIVA]->(florestas),
(halflings)-[:RELACAO_POSITIVA]->(tempestades),
(halflings)-[:RELACAO_POSITIVA]->(antigos),
(dragoes)-[:RELACAO_POSITIVA]->(altharia),
(dragoes)-[:RELACAO_POSITIVA]->(aventus),
(civilizacoes)-[:RELACAO_POSITIVA]->(altharia)
CREATE (altharia:Loc_assentamento {nome: "Altharia", descrição: "Reino onde os avanços tecnológicos desempenham um papel crucial no desenvolvimento e nas interações sociais"}),
(armas:Objeto {nome: "Armas e Armaduras Avançadas", descrição: "Inovações nas técnicas de forjamento de armas e armaduras, resultando em lâminas mais afiadas e resistentes e placas de armadura mais ajustadas e leves"}),
(armas_siege:Objeto {nome: "Armas de Cerco Avançadas", descrição: "Aperfeiçoamentos na fabricação de armas de cerco, permitindo ataques mais eficazes a fortalezas e castelos"}),
(mineracao:Tecnologia {nome: "Técnicas de Mineração Avançadas", descrição: "Aprimoramentos nas técnicas de mineração, permitindo a extração de minérios preciosos de forma mais eficiente"}),
(agricultura:Tecnologia {nome: "Técnicas Agrícolas Avançadas", descrição: "Introdução de novas técnicas agrícolas, como sistemas de irrigação avançados e melhores métodos de plantio"}),
(carruagens:Veiculo {nome: "Carruagens Mágicas", descrição: "Carruagens alimentadas por cristais arcanos, permitindo o transporte rápido de mercadorias entre cidades distantes"}),
(comunicacao:Tecnologia {nome: "Dispositivos Mágicos de Comunicação", descrição: "Criação de dispositivos mágicos de comunicação, como amuletos de fala distante, permitindo a troca de informações instantânea entre diferentes pontos do reino"}),
(esferas:Objeto {nome: "Esferas de Invocação", descrição: "Dispositivos mágicos poderosos que podem ser utilizados para fins malignos"}),
(amuletos:Objeto {nome: "Amuletos de Controle Mental", descrição: "Dispositivos mágicos que permitem o controle mental, podendo ser utilizados para fins malignos"}),
(comercio:Drama {nome: "Dinâmicas Econômicas", descrição: "Impacto da tecnologia nas dinâmicas econômicas de Altharia"}),
(conflito_tecnologia:Drama {nome: "Conflitos Tecnológicos", descrição: "Tensões e conflitos resultantes do uso indevido de avanços tecnológicos"}),
(altharia)-[:ESTA_EM]->(comercio),
(altharia)-[:ESTA_EM]->(conflito_tecnologia),
(armas)-[:ESTA_EM]->(altharia),
(armas_siege)-[:ESTA_EM]->(altharia),
(mineracao)-[:ESTA_EM]->(altharia),
(agricultura)-[:ESTA_EM]->(altharia),
(carruagens)-[:ESTA_EM]->(altharia),
(comunicacao)-[:ESTA_EM]->(altharia),
(esferas)-[:ESTA_EM]->(altharia),
(amuletos)-[:ESTA_EM]->(altharia),
(armas)-[:RELACAO_POSITIVA]->(comercio),
(armas_siege)-[:RELACAO_POSITIVA]->(comercio),
(mineracao)-[:RELACAO_POSITIVA]->(comercio),
(agricultura)-[:RELACAO_POSITIVA]->(comercio),
(carruagens)-[:RELACAO_POSITIVA]->(comercio),
(comunicacao)-[:RELACAO_POSITIVA]->(comercio),
(esferas)-[:RELACAO_NEGATIVA]->(conflito_tecnologia),
(amuletos)-[:RELACAO_NEGATIVA]->(conflito_tecnologia)
CREATE (altharia:Loc_assentamento {nome: "Altharia", descrição: "Continente com uma sociedade diversa e perigosa"}),
(musica:Objeto {nome: "Música", descrição: "Uma forma de expressão artística valorizada e reverenciada por todas as raças e classes sociais"}),
(danca:Objeto {nome: "Dança", descrição: "Uma forma de expressão artística que serve como entretenimento e meio de contar histórias"}),
(pintura:Objeto {nome: "Pintura", descrição: "Uma forma de expressão artística apreciada em toda Altharia"}),
(poesia:Objeto {nome: "Poesia", descrição: "Uma forma de expressão artística valorizada em Altharia"}),
(literatura:Objeto {nome: "Literatura", descrição: "Uma forma de expressão artística valorizada em Altharia"}),
(elfos:Especie {nome: "Elfos", descrição: "Raça habilidosa com o arco, dominando as cordas de lira e harpa"}),
(anoes:Especie {nome: "Anões", descrição: "Raça habilidosa na forja, criando instrumentos de percussão"}),
(humanos:Especie {nome: "Humanos", descrição: "Raça diversa com uma variedade de estilos musicais"}),
(gnomos:Especie {nome: "Gnomos", descrição: "Raça conhecida por sua energia contagiante e danças animadas"}),
(hobbits:Especie {nome: "Hobbits", descrição: "Raça que escreve histórias encantadoras que trazem alegria e humor"}),
(montanhas:Loc_assentamento {nome: "Montanhas", descrição: "Região onde os anões criam murais intrincados nas paredes de suas cidades subterrâneas"}),
(elfos)-[:ESTA_EM]->(altharia),
(elfos)-[:ESTA_EM]->(musica),
(anoes)-[:ESTA_EM]->(altharia),
(anoes)-[:ESTA_EM]->(musica),
(humanos)-[:ESTA_EM]->(altharia),
(humanos)-[:ESTA_EM]->(musica),
(gnomos)-[:ESTA_EM]->(altharia),
(gnomos)-[:ESTA_EM]->(danca),
(anoes)-[:ESTA_EM]->(montanhas),
(anoes)-[:ESTA_EM]->(pintura),
(elfos)-[:ESTA_EM]->(pintura),
(humanos)-[:ESTA_EM]->(pintura),
(elfos)-[:ESTA_EM]->(poesia),
(hobbits)-[:ESTA_EM]->(poesia),
(humanos)-[:ESTA_EM]->(poesia),
(hobbits)-[:ESTA_EM]->(literatura),
(humanos)-[:ESTA_EM]->(literatura)

Por favor, processe e remova todas as entradas duplicadas, garantindo que a query retornará apenas nós ou relações únicas."""

print(prompt_resume_query)
# Out:
# Dada a seguinte query Cypher do Neo4j:
#
# CREATE (altharia:Loc_assentamento {nome: "Altharia", descrição: "Um vasto continente onde a magia flui e auras místicas pintam o céu"}),
# (sirian:Personagem {nome: "Sirian", descrição: "Um guerreiro valente e honrado, líder do grupo de aventureiros"}),
# (cidadela:Construcao {nome: "Cidadela dos Sonhos", descrição: "Um local misterioso e encantado onde a realidade e os sonhos se entrelaçam"}),
# (sussurros:Personagem {nome: "Sussurros", descrição: "Seres etéreos que guardam a Cidadela dos Sonhos"}),
# (floresta:Loc_assentamento {nome: "Floresta Proibida de Eldreth", descrição: "Uma floresta sombria habitada por criaturas fantásticas"}),
# (pedra:Objeto {nome: "Pedra da Eternidade", descrição: "Um artefato sagrado enterrado na Floresta Proibida de Eldreth"}),
# (anciao:Personagem {nome: "Ancião das Árvores", descrição: "Guardião da Floresta Proibida de Eldreth"}),
# ...

# %%
cypher_bg_all = api_t0_16k.predict_messages([SystemMessage(content=prompt_resume_query),
                                      HumanMessage(content=cypher_all)])
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 cypher_bg_all = api_t0_16k.predict_messages([SystemMessage(content=prompt_resume_query),
#       2                                       HumanMessage(content=cypher_all)])
#
# File E:\Documentos\Estudos\UFRJ_PESC\3_periodo\llm\projeto final\COS836-2023-2-LLM\src\venv\Lib\site-packages\langchain\chat_models\base.py:399, in BaseChatModel.predict_messages(self, messages, stop, **kwargs)
#     397 else:
#     398     _stop = list(stop)
# --> 399 return self(messages, stop=_stop, **kwargs)
#
# File E:\Documentos\Estudos\UFRJ_PESC\3_periodo\llm\projeto final\COS836-2023-2-LLM\src\venv\Lib\site-packages\langchain\chat_models\base.py:349, in BaseChatModel.__call__(self, messages, stop, callbacks, **kwargs)
#     342 def __call__(
#     343     self,
#     344     messages: List[BaseMessage],
#    (...)
# ...

# %%
print(cypher_bg_all.content)
# Out:
# CREATE (Ethoria:Lugar {nome: 'Ethoria', descrição: 'Terra distante onde a magia e a aventura se entrelaçam'})
# CREATE (Chambral:Lugar {nome: 'Chambral', descrição: 'Reino repleto de altas montanhas e florestas densas'})
# CREATE (Eardam:Personagem {nome: 'Eardam', descrição: 'Rei de Chambral conhecido por sua sabedoria e justiça'})
# CREATE (CidadeDePedra:Lugar {nome: 'Cidade de Pedra', descrição: 'Capital de Chambral, um local agitado, cheio de mercadores animados e tabernas barulhentas'})
# CREATE (EstrelasDoDragão:Organização {nome: 'Estrelas do Dragão', descrição: 'Renomada guilda de caçadores de dragões em Chambral'})
# CREATE (Alden:Lugar {nome: 'Alden', descrição: 'Reino conhecido por sua classe guerreira e arquitetura grandiosa'})
# CREATE (Amara:Personagem {nome: 'Amara', descrição: 'Rainha de Alden, uma estrategista habilidosa'})
# CREATE (Velastra:Objeto {nome: 'Velastra', descrição: 'Espada lendária forjada nas profundezas de uma masmorra ancestral em Alden'})
# ...

# %% [markdown]
# # Testing on Neo4j

# %%
from neo4j import GraphDatabase

# Connect to the Neo4j database
uri = "bolt://localhost:7687"
username = "neo4j"
password = "12345678"
driver = GraphDatabase.driver(uri, auth=(username, password))

# %%
def wipe_database(tx):
    tx.run("MATCH (n) DETACH DELETE n")

with driver.session() as session:
    session.write_transaction(wipe_database)
# Out:
# C:\Users\rafae\AppData\Local\Temp\ipykernel_59440\1445805520.py:5: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(wipe_database)

# %%
cypher_content = """CREATE (asthael:Loc_assentamento {nome: "Asthael", descrição: "Reino mergulhado em misticismo profundo"}),
(caldera:Construcao {nome: "Caldera das Almas", descrição: "Antigo caldeirão com poder oculto que atrai a atenção de várias facções"}),
(sociedade:Organizacao {nome: "Sociedade dos Selos", descrição: "Organização sombria que busca controlar a Caldera para alcançar seus próprios objetivos desconhecidos"}),
(conclave:Organizacao {nome: "Conclave dos Anciãos", descrição: "Grupo de sábios que vê na Caldera uma chance de salvar o mundo de uma catástrofe iminente"}),
(kyron:Personagem {nome: "Kyron", descrição: "Guerreiro solitário em busca de vingança contra o dragão Vermelho-Negro"}),
(espada_aurora:Objeto {nome: "Espada da Aurora", descrição: "Artefato lendário capaz de derrotar o dragão Vermelho-Negro"}),
(lirael:Personagem {nome: "Lirael", descrição: "Elfa arqueira com arco encantado e habilidades excepcionais"}),
(casas_nobres:Organizacao {nome: "Casas Nobres", descrição: "Duas grandes casas nobres envolvidas em uma guerra com magia negra e criaturas sombrias"}),
(povo:Organizacao {nome: "Povo", descrição: "População do reino que sofre nas mãos das disputas entre as Casas Nobres"}),
(batalhas:Drama {nome: "Batalhas épicas", descrição: "Conflitos intensos e épicos que ocorrem no reino"}),
(magia:Drama {nome: "Magia intensa", descrição: "Uso poderoso e intenso de magia no reino"}),
(aliados:Organizacao {nome: "Aliados", descrição: "Personagens que se juntam a Lirael e Kyron para proteger a Caldera das Almas"}),
(inimigos:Organizacao {nome: "Inimigos", descrição: "Personagens formidáveis que enfrentam Lirael e Kyron na busca pela Caldera das Almas"})

CREATE (caldera)-[:ESTA_EM]->(asthael),
(sociedade)-[:ESTA_EM]->(caldera),
(conclave)-[:ESTA_EM]->(caldera),
(kyron)-[:ESTA_EM]->(asthael),
(espada_aurora)-[:ESTA_EM]->(kyron),
(lirael)-[:ESTA_EM]->(asthael),
(lirael)-[:PROPRIETARIO_DE]->(espada_aurora),
(lirael)-[:RELACAO_POSITIVA]->(kyron),
(asthael)-[:AFETADO_POR]->(batalhas),
(asthael)-[:AFETADO_POR]->(magia),
(asthael)-[:AFETADO_POR]->(casas_nobres),
(povo)-[:ESTA_EM]->(asthael),
(casas_nobres)-[:RELACAO_NEGATIVA]->(povo),
(lirael)-[:MEMBRO_DE]->(aliados),
(kyron)-[:MEMBRO_DE]->(aliados),
(lirael)-[:RELACAO_POSITIVA]->(caldera),
(kyron)-[:RELACAO_POSITIVA]->(caldera),
(lirael)-[:RELACAO_POSITIVA]->(aliados),
(kyron)-[:RELACAO_POSITIVA]->(aliados),
(lirael)-[:RELACAO_NEGATIVA]->(inimigos),
(kyron)-[:RELACAO_NEGATIVA]->(inimigos)"""

# %%
with driver.session() as session:
#    session.run(cypher_bg_all.content)
     session.run(cypher_content)

# %%
def get_triplets(tx):
    result = tx.run("MATCH (n)-[r]->(m) RETURN n, r, m")
    return [(record["n"]["nome"], record["r"].type, record["m"]["nome"]) for record in result]

with driver.session() as session:
    triplets = session.read_transaction(get_triplets)

#for triplet in triplets:
#    print(triplet)
triplets = "\n".join([str(x) for x in triplets])
print(triplets)
# Out:
# ('Caldera das Almas', 'ESTA_EM', 'Asthael')
# ('Sociedade dos Selos', 'ESTA_EM', 'Caldera das Almas')
# ('Conclave dos Anciãos', 'ESTA_EM', 'Caldera das Almas')
# ('Kyron', 'ESTA_EM', 'Asthael')
# ('Espada da Aurora', 'ESTA_EM', 'Kyron')
# ('Lirael', 'ESTA_EM', 'Asthael')
# ('Lirael', 'PROPRIETARIO_DE', 'Espada da Aurora')
# ('Lirael', 'RELACAO_POSITIVA', 'Kyron')
# ('Asthael', 'AFETADO_POR', 'Batalhas épicas')
# ('Asthael', 'AFETADO_POR', 'Magia intensa')
# ('Asthael', 'AFETADO_POR', 'Casas Nobres')
# ('Povo', 'ESTA_EM', 'Asthael')
# ('Casas Nobres', 'RELACAO_NEGATIVA', 'Povo')
# ('Lirael', 'MEMBRO_DE', 'Aliados')
# ('Kyron', 'MEMBRO_DE', 'Aliados')
# ('Lirael', 'RELACAO_POSITIVA', 'Caldera das Almas')
# ('Kyron', 'RELACAO_POSITIVA', 'Caldera das Almas')
# ('Lirael', 'RELACAO_POSITIVA', 'Aliados')
# ('Kyron', 'RELACAO_POSITIVA', 'Aliados')
# ('Lirael', 'RELACAO_NEGATIVA', 'Inimigos')
# ('Kyron', 'RELACAO_NEGATIVA', 'Inimigos')
# ...

# %%
def get_entities_and_properties(tx):
    result = tx.run("MATCH (n) RETURN n")
    return [(record["n"]["nome"], dict(record["n"].items())) for record in result]

with driver.session() as session:
    entities = session.read_transaction(get_entities_and_properties)

#for entity in entities:
#    print(entity)

entities = "\n".join([str(x) for x in entities])
print(entities)
# Out:
# ('Asthael', {'descrição': 'Reino mergulhado em misticismo profundo', 'nome': 'Asthael'})
# ('Caldera das Almas', {'descrição': 'Antigo caldeirão com poder oculto que atrai a atenção de várias facções', 'nome': 'Caldera das Almas'})
# ('Sociedade dos Selos', {'descrição': 'Organização sombria que busca controlar a Caldera para alcançar seus próprios objetivos desconhecidos', 'nome': 'Sociedade dos Selos'})
# ('Conclave dos Anciãos', {'descrição': 'Grupo de sábios que vê na Caldera uma chance de salvar o mundo de uma catástrofe iminente', 'nome': 'Conclave dos Anciãos'})
# ('Kyron', {'descrição': 'Guerreiro solitário em busca de vingança contra o dragão Vermelho-Negro', 'nome': 'Kyron'})
# ('Espada da Aurora', {'descrição': 'Artefato lendário capaz de derrotar o dragão Vermelho-Negro', 'nome': 'Espada da Aurora'})
# ('Lirael', {'descrição': 'Elfa arqueira com arco encantado e habilidades excepcionais', 'nome': 'Lirael'})
# ...

# %% [markdown]
# # Graph to text and other tasks

# %%
prompt_system_g2t = """Você é um programador profissional que lê uma lista de triplets, assim como uma lista de entidades e propriedades, e escreve uma código em Cypher para o banco de dados Neo4j, que realiza a tarefa solicitada. Utilize o Neo4j Python Driver.

A lista de triplets é gerada pelo seguinte código, delimitado por '<código python>':

<código python> from neo4j import GraphDatabase
driver = GraphDatabase.driver(uri, auth=(username, password))


def get_triplets(tx):
    result = tx.run("MATCH (n)-[r]->(m) RETURN n, r, m")
    return [(record["n"]["nome"], record["r"].type, record["m"]["nome"]) for record in result]


with driver.session() as session:
    triplets = session.read_transaction(get_triplets)

for triplet in triplets:
    print(triplet)
<código python>

A lista de entidades e suas propriedades é gerada pelo seguinte código, delimitado por '<código python>':

<código python> from neo4j import GraphDatabase
driver = GraphDatabase.driver(uri, auth=(username, password))


def get_entities_and_properties(tx):
    result = tx.run("MATCH (n) RETURN n")
    return [(record["n"]["nome"], dict(record["n"].items())) for record in result]


with driver.session() as session:
    entities = session.read_transaction(get_entities_and_properties)

for entity in entities:
    print(entity)
<código python>
"""

prompt_human_g2t = ("A lista de triplets está a seguir: \n" + triplets + 
                   "\n \n A lista de entidades e suas propriedades está a seguir: \n" + entities + 
""" \n \n Você é um escritor profissional fazendo o worldbuilding e um mundo de RPG. 

Você deve considerar os seguintes aspectos, mas nunca falar sobre eles diretamente:
1. O gênero é ficção;
2. O mundo parece místico;
3. O tom da história é leve;
4. O mundo tem masmorras e dragões como temas recorrentes;
5. O nível de tecnologia é medieval,
6. O nível de magia é raro,
7. A atmosfera é inspiradora,
8. A história é inspirada nos escritores George R. R. Martin, J. R. R. Tolkien, Matthew Mercer e Brennan Lee Mulligan,
""" +
                   "Com base nesses dados, escreva a história representada em 15 parágrafos na estrutura de uma história de ficção.")

# %%
g2t = api_cypher.predict_messages([SystemMessage(content=prompt_system_g2t),
                                   HumanMessage(content=prompt_human_g2t)])

# %%
print(g2t.content)
# Out:
# Eldoria, um reino distante onde a magia e a aventura se entrelaçam, é o cenário principal desta história mística. Em Arkania, um reino conhecido por seu sistema de justiça imparcial e seus governantes justos, o Rei sábio e benevolente governa com sabedoria. Porém, Arkania não está livre de ameaças, e a Ordem das Mãos de Prata, uma organização de honrados cavaleiros, é responsável por garantir a paz no reino.
#
# Mas uma sombra sinistra paira sobre Arkania. A Sombra Crescente, uma sociedade secreta enigmática e ameaçadora, busca minar a paz e a estabilidade do reino. Enquanto isso, nas Montanhas do Trovão, uma região onde Flamewrath, o temido dragão vermelho, ameaça a paz, a Guilda dos Desbravadores, uma congregação de aventureiros corajosos, enfrenta os perigos e desafios que surgem.
#
# ...

# %% [markdown]
# # Testing metrics

# %%
from evaluate import load
bertscore = load("bertscore")

predictions = [full_bg]
references = [g2t.content]

#predictions = [prompt1]
#references = [prompt2]

results = bertscore.compute(predictions=predictions, references=references, model_type="distilbert-base-uncased")

# %%
results
# Out:
# {'precision': [0.8756647109985352],
#  'recall': [0.8785662651062012],
#  'f1': [0.8771131038665771],
#  'hashcode': 'distilbert-base-uncased_L5_no-idf_version=0.3.12(hug_trans=4.30.2)'}
