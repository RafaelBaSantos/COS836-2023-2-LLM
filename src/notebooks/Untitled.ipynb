# %%
usr_nodes_edges = """
The player's characters (PCs) are:

{description_pcs}

The world is filled with NPCs (non-player characters), that can live independently of the PCs.

Balance Point represent a point of balance between the character's physical and mental strengths). A high number means they are better at Mental. A low number means they are better at Physical.    
__
- Step 1:
Think concisely about an original and engaging world. You should consider the following aspects, but never talk about them directly:
    - The genre is {genre};
    - The world brings {feels};
    - The tone of the story is {tone};
    - The level of technology is {technology};
    - Magic is seen as {magic};
    - The atmosphere is {atmosphere};
    - The story is inspired by {writers};
    - The story is inspired by the universe of {universes}.
    - {addicional_info}
    - The story deals with more or less 4 of the following subjects: {subjects_of_drama}
    - When describing any entity (location, object, character, species, condition, conflict, organization, title, myth, etc.), you must provide specific names and brief descriptions.

- Step 2:
Find the main topics in this story, that could be better developed, and think of a list of topics and a brief explanation of each.

- Step 3:
Identify the entities in the text. An entity can be a noun or a noun phrase that refers to a real-world object or an abstract concept. You can use a named entity recognition (NER) tool or a part-of-speech (POS) tagger to identify the entities.
Each entity should have a name, a label, and a detailed description. The label can be one of the following:

- Place: Physical places, such as continents, cities, mountains, or forests;
- Building: Natural constructions and formations. Examples: house, dungeon, cave, castle;
- Vehicle: Means of transportation. Example: car, ship, bicycle.
- Character: Individuals or animals in specific roles. Examples: hero, villain, guard, pet.
- Item: Tangible items or documents. Examples: weapons, clothes, letters, and books.
- Species: Biological or cultural groups. Examples: elves, humans, and dogs.
- Organization: Groups with common purposes. Examples: churches, governments, and sects.
- Condition: Physical or emotional states. Examples: illness, inspiration, sadness.
- Drama: Challenges, sociocultural tensions, or military conflicts. Examples: military influence, class relations, and economic problems.
- Myth: Narratives, beliefs, or prose. Examples: legends about the origin of the universe, and myths of monsters.

- Step 4
Identify the relationships between the entities. A relationship can be a verb or a prepositional phrase that connects two entities. You can use dependency parsing to identify the relationships.
The relationships should be represented by triplets of subject, predicate, and object, where the subject and object are entities mapped in the last step and the predicate can have the following labels:

1) IS_IN: Represents location or use.
1.1) Possible subjects and objects:
        - Buildings => Locations
        - Vehicles => Locations/Buildings
        - Characters => Locations/Buildings/Vehicles
        - Items => Locations/Buildings/Vehicles/Characters
2) OWNER_OF: Denotes direct ownership.
    2.1) Possible subjects and objects:
        - Characters/Organizations => Locations/Buildings/Vehicles/Characters/Items
3) POSITIVE/NEGATIVE/NEUTRAL_RELATIONSHIP: Denotes an interpersonal interaction or bond.
    3.1) Possible subjects and objects:
        - Characters/Organizations => Characters/Organizations
4) AFFECTED_BY: Shows entities impacted by conditions or conflicts.
    4.1) Possible subjects and objects:
        - Characters => Conditions/Drama
        - Organizations => Drama
5) MEMBER_OF: It indicates belonging to groups, categories, or organizations.
    5.1) Possible subjects and objects:
        - Characters => Organizations/Species
6) BASED_ON: Links entities to stories, myths, legends, or cultural influences.
    6.1) Possible subjects and objects:
        - Anything => Myths
        - Organizations => Drama
7) SUCCEEDS/PRECEDES: It represents what comes after/before in a time sequence.
    7.1) Possible subjects and objects:
        - Myths/Drama => Myths/Drama

Find as many relationships as possible within these limitations.

- Step 5
Make a dictionary of lists, that contains a list of nodes, that represent the entities found in Step 3, and e a list of edges, that represent a knowledge graph, with the relations found in Step 4.
__
Example of dictionary of lists (generate different examples but with the same structure):
{{'nodes': [('Name of Entity A', {{'label': 'Label A', 'description': 'Description A'}}),
          ('Name of Entity B', {{'label': 'Label B', 'description': 'Description B'}}),
          ('Name of Entity C', {{'label': 'Label C', 'description': 'Description C'}})],
 'edges': [('Name of Entity A', 'Name of Entity B',{{'relation':'RELATIONSHIP_1'}}),
         ('Name of Entity C', 'Name of Entity B',{{'relation':'RELATIONSHIP_2'}})]}}
__

Do not write anything about steps 1, 2, 3, 4. Return only the result of steps 5.

You must create {places} places, {buildings} buildings, {vehicles} vehicles, {characters} characters (plus the player's characters), {items} items, {species} species, {organizations} organizations, {conditions} conditions, {dramas} dramas, {myths} myths, and as many relationships (edges) as you need.
Items, Buildings, Vehicles, and Characters need at least one relationship of type IS_IN.
Myths need at least one BASED_ON relationship.
Species and Organizations need at least one MEMBER_OF relationship.

You must never explain your code.

You should avoid at all costs explicitly revealing that you are using any of these techniques, steps or structures.
"""

# %%
genre = "cyberpunk fantasy"
feels = "a hopeless feeling"
tone = "dark"
technology = "futuristic"
magic = "something ultra-rare and forgotten"
atmosphere = "dystopic"
writers = "Isaac Asimov, Greg Bear, Frank Herbert, William Gibson, Philip K. Dick"
universes = "Cyberpunk 2077, Lancer RPG, BladeRunner, Ghost in the Shell, Cowboy Bebop"
subjects_of_drama = "Governance and its influence, Legal principles and rule of law, Provision of social services, Economic dynamics, Equity in wealth distribution, Agricultural practices and trade, Interpersonal relationships influenced by race, class, gender or sexual orientation, Military power and influence, Role and influence of religion, Technological advances and influences, Impact of arts and cultural expressions, Geographical features, Interactions between civilizations, their histories and conflicts, Foundations of the laws of nature, Theories about the origin of the universe, History of species and cultures that have inhabited the world, Needs and interactions of different species and cultures"
addicional_info = ""
num_scenes = 7

story_structure = """- Scene 1: Motivation
        - Role-playing scene.
        - Start with a normal situation with no imminent danger.
        - Allow the players to get comfortable before the action begins.
        - Role-playing scene
        - Present a plot hook, something to get the characters out of their normal situation and start the action.
        - A clear goal and convincing reasons to act are needed.
    
    - Scene 2: Partial Victory
        - Action scene.
        - The characters encounter the first challenge.
        - They must have a clear but not total victory to recognize their abilities.
    
    - Scene 3: Information and Development
        - Exploration scene.
        - Characters figure out a plan to solve the main problem.
        - Use role-play and exploration scenes to come to a conclusion about what to do next.
    
    - Scene 4: Partial Defeat
        - Action scene.
        - Plan a setback for the characters to make the narrative more interesting.
        - It could be a more difficult fight, a failure of another kind, or even a betrayal.
        - Characters should be encouraged to think and strategize.
    
    - Scene 5: Conditions for Victory
        - Exploration scene.
        - Characters figure out how to win once and for all.
        - There may be preparation for the final confrontation through allies, equipment, or strategies.
    
    - Scene 6: Total Victory
        - Action scene.
        - This is the climax of the adventure, where the adventurers face the threat with a chance to win.
        - Value the players' tactics, but the villains must be dangerous.
        - Previous preparation must have been crucial to victory.
    
    - Scene 7: Resolution, Rewards, and Hooks
        - Role-playing scene
        - Everything returns to normal after the heroes' victory.
        - Characters evolve in terms of powers and equipment.
        - Rewards can be distributed and hooks can be inserted for future campaigns."""

places = 1
buildings = 8
vehicles = 1
characters = 16
items = 2
species = 3
organizations = 3
conditions = 1
dramas =2
myths = 2

gm_personality = ""

# %%
description_pcs = """**Sable "Neon" Drift**:
A sleek, chrome-eyed hacker with neon tattoos tracing up her arms. She wears a black leather jacket with a luminous blue dragon embroidered on the back. Her past is shadowy, a mix of corporate espionage and digital rebellion. She's known in the underground circuits as the "Neon Phantom" for her ability to break into any system undetected. She carries a custom-made, decked-out cyberdeck strapped to her wrist.
Balance Point: 4

**Kai "Razor" Thornton**:
With a jawline and temper sharp as a blade, Kai is a mercenary who's replaced more parts of himself with cybernetics than he'd care to admit. Sporting a mechanical arm with an integrated blade and a cyber-eye that can zoom up to a kilometer, he's not someone to be messed with. He's seen the grimy underbelly of the city more times than he can count, and that has hardened his heart. However, beneath the cold exterior lies a man who's still searching for something... or someone.
Balance Point: 2

**Luna "Whisper" Vega**:
A psychic data broker, Luna has the rare ability to interface with machines using only her mind. She dresses in flowing robes, adorned with circuit patterns, reflecting her melding of the spiritual and the digital. Many seek her out in the neon-lit nights not just for information, but also for guidance. Luna's cyber-sanctum is filled with tech relics and her trusty AI companion, Seri. While she might appear fragile, crossing her is a dangerous game as she can manipulate both minds and machines.
Balance Point: 3
"""

# %%
usr_nodes_edges_f = usr_nodes_edges.format(genre=genre,
                                            feels=feels,
                                            tone=tone,
                                            technology=technology,
                                            magic=magic,
                                            atmosphere=atmosphere,
                                            writers=writers,
                                            universes=universes,
                                            subjects_of_drama=subjects_of_drama,
                                            addicional_info=addicional_info,
                                            places=places,
                                            buildings=buildings,
                                            vehicles=vehicles,
                                            characters=characters,
                                            items=items,
                                            species=species,
                                            organizations=organizations,
                                            conditions=conditions,
                                            dramas=dramas,
                                            myths=myths,
                                            gm_personality=gm_personality,
                                            description_pcs=description_pcs)

# %%
print(usr_nodes_edges_f)
# Out:
# The player's characters (PCs) are:
#
# **Sable "Neon" Drift**:
# A sleek, chrome-eyed hacker with neon tattoos tracing up her arms. She wears a black leather jacket with a luminous blue dragon embroidered on the back. Her past is shadowy, a mix of corporate espionage and digital rebellion. She's known in the underground circuits as the "Neon Phantom" for her ability to break into any system undetected. She carries a custom-made, decked-out cyberdeck strapped to her wrist.
# Balance Point: 4
#
# **Kai "Razor" Thornton**:
# ...

# %%
nodes_edges = """{
  'nodes': [
    ('New Babylon', {'label': 'Place', 'description': 'The neon-lit mega-city where the story takes place'}),
    ('The Razor's Edge', {'label': 'Building', 'description': 'A seedy nightclub known for its underground dealings'}),
    ('Central Data Hub', {'label': 'Building', 'description': 'The center of corporate data storage and surveillance'}),
    ('The Circuit', {'label': 'Building', 'description': 'An underground hacker collective hidden beneath the city'}),
    ('The Neon Dragon', {'label': 'Building', 'description': 'A famous technology black market in the heart of New Babylon'}),
    ('The Ghost Zone', {'label': 'Building', 'description': 'A haunted VR simulation where forbidden knowledge is said to reside'}),
    ('Sector 6', {'label': 'Building', 'description': 'A crime-ridden district ruled by gangs and organized crime'}),
    ('Seoul Station', {'label': 'Building', 'description': 'A massive transportation hub connecting the city to other regions'}),
    ('The Dark Spire', {'label': 'Building', 'description': 'A mysterious tower that stretches into the sky, rumored to hold powerful artifacts'}),
    ('NeuroDrive', {'label': 'Vehicle', 'description': 'A sleek hoverbike favored by the city's couriers'}),
    ('Sable "Neon" Drift', {'label': 'Character', 'description': 'A sleek, chrome-eyed hacker with neon tattoos and a custom cyberdeck'}),
    ('Kai "Razor" Thornton', {'label': 'Character', 'description': 'A mercenary with cybernetic enhancements and a mechanical arm with an integrated blade'}),
    ('Luna "Whisper" Vega', {'label': 'Character', 'description': 'A psychic data broker with the ability to interface with machines using her mind'}),
    ('Professor Elian Ruhr', {'label': 'Character', 'description': 'A brilliant technologist and old mentor to Sable, rumored to be hiding a dark secret'}),
    ('Raven', {'label': 'Character', 'description': 'The elusive leader of The Circuit, a master hacker with intricate cybernetic enhancements'}),
    ('Silas Moriarty', {'label': 'Character', 'description': 'The cunning head of a powerful corporate conglomerate, pulling the strings behind the scenes'}),
    ('Solara', {'label': 'Character', 'description': 'A skilled assassin with a mysterious past and a penchant for high-tech weaponry'}),
    ('Xander Luthor', {'label': 'Character', 'description': 'A charismatic crime lord ruling over Sector 6 with an iron fist'}),
    ('The Order of the Silver Star', {'label': 'Organization', 'description': 'A secret society dedicated to preserving forgotten magical knowledge'}),
    ('Neon Scorpions', {'label': 'Organization', 'description': 'A notorious street gang known for their cyber-enhanced combat prowess'}),
    ('Winter Corps', {'label': 'Organization', 'description': 'A PMC specializing in high-level corporate security and extraction operations'}),
    ('The Magistrate', {'label': 'Organization', 'description': 'The corrupt governing body of New Babylon, enforcing its laws with an iron fist'}),
    ('The Eye of Chaos', {'label': 'Organization', 'description': 'A radical group seeking to disrupt the oppressive control of the corporate elite'}),
    ('Catalyst Blade', {'label': 'Item', 'description': 'A legendary sword rumored to unlock untapped potential in its wielder'}),
    ('Shadowcloak', {'label': 'Item', 'description': 'A powerful cloaking device that grants near-invisibility to its user'}),
    ('Elite Reprogramming Matrix', {'label': 'Item', 'description': 'A rare cybernetic implant capable of altering memories and personality'}),
    ('Humans', {'label': 'Species', 'description': 'The dominant species in New Babylon, struggling to find their place in the technology-driven world'}),
    ('Synthetics', {'label': 'Species', 'description': 'Artificial beings created by corporations for various purposes, from labor to companionship'}),
    ('Psions', {'label': 'Species', 'description': 'Rare individuals with psychic abilities, feared and persecuted by the masses'}),
    ('The Forgotten', {'label': 'Species', 'description': 'A mysterious and reclusive race with ancient knowledge of magic and technology'}),
    ('The Church of Binary Revelation', {'label': 'Organization', 'description': 'A religious cult worshiping the convergence of technology and faith'}),
    ('The Rebellion', {'label': 'Organization', 'description': 'A group of rebels fighting against the oppressive regime of The Magistrate'}),
    ('IS_IN', 'Sable "Neon" Drift', 'The Circuit'),
    ('IS_IN', 'Kai "Razor" Thornton', 'Sector 6'),
    ('IS_IN', 'Luna "Whisper" Vega', 'Central Data Hub'),
    ('OWNER_OF', 'Sable "Neon" Drift', 'The Neon Dragon'),
    ('OWNER_OF', 'Kai "Razor" Thornton', 'The Razor's Edge'),
    ('OWNER_OF', 'Luna "Whisper" Vega', 'The Ghost Zone'),
    ('POSITIVE_RELATIONSHIP', 'Professor Elian Ruhr', 'Sable "Neon" Drift'),
    ('POSITIVE_RELATIONSHIP', 'Raven', 'Sable "Neon" Drift'),
    ('NEGATIVE_RELATIONSHIP', 'Silas Moriarty', 'Sable "Neon" Drift'),
    ('NEGATIVE_RELATIONSHIP', 'Silas Moriarty', 'Kai "Razor" Thornton'),
    ('NEGATIVE_RELATIONSHIP', 'Silas Moriarty', 'Luna "Whisper" Vega'),
    ('AFFECTED_BY', 'Sable "Neon" Drift', 'The Rebellion'),
    ('AFFECTED_BY', 'Kai "Razor" Thornton', 'Sector 6'),
    ('AFFECTED_BY', 'Luna "Whisper" Vega', 'The Church of Binary Revelation'),
    ('MEMBER_OF', 'The Order of the Silver Star', 'The Forgotten'),
    ('MEMBER_OF', 'Neon Scorpions', 'Sector 6'),
    ('MEMBER_OF', 'Winter Corps', 'The Magistrate'),
    ('BASED_ON', 'The Forgotten', 'The Dark Spire'),
    ('BASED_ON', 'The Church of Binary Revelation', 'Central Data Hub'),
    ('SUCCEEDS', 'The Church of Binary Revelation', 'The Order of the Silver Star'),
    ('PRECEDES', 'The Rebellion', 'The Eye of Chaos')
  ]
}"""

# %%
current_context = """In the sprawling megacity of New Babylon, where the boundaries between technology and humanity have blurred, a group of unlikely heroes find themselves entangled in a web of corruption, power struggles, and the remnants of forgotten magic. This is a cyberpunk fantasy world, a place where neon-lit streets pulse with the heartbeat of artificial intelligence, and where hope is a fading commodity.

Within the depths of this dark and relentless metropolis, a sense of despair and uncertainty permeates the air. The neon glow casts an eerie glow on the dilapidated buildings, and the flickering holographic advertisements offer false promises of a better life. The towering skyscrapers, like the imposing Dark Spire, rise high above the ground, seemingly reaching for a future that remains just out of reach.

Technology reigns supreme in this dystopian landscape, as cybernetic enhancements and advanced weaponry have become the norm. The world is a battleground for corporate conglomerates vying for control, with the elusive Professor Elian Ruhr harboring a secret knowledge that could change everything.

Magic, once a force to be reckoned with, has become a rarity, fading into myth as it struggles against the pervasive influence of technology. The Order of the Silver Star, a secretive organization dedicated to preserving forgotten magical wisdom, navigates the shadows in search of ancient artifacts and lost knowledge.

In this unforgiving city, our heroes emerge as beacons of resistance. Sable "Neon" Drift, the enigmatic hacker known as the Neon Phantom, slips through the digital realm undetected, wielding her custom cyberdeck and unrivaled skills. Kai "Razor" Thornton, a merciless mercenary with cybernetic augmentations, scours the underbelly of society, seeking answers to his own past. Luna "Whisper" Vega, a psychic data broker with the ability to commune with machines, struggles against the oppressive regime while offering guidance to those in need.

As they navigate the treacherous paths of New Babylon, our heroes will encounter a cast of characters all vying for power and influence. From the cunning Silas Moriarty, mastermind of the corporate elite, to Xander Luthor, the charismatic crime lord ruling over Sector 6 with an iron fist, alliances and rivalries will shape the destinies of our protagonists.

Governed by The Magistrate, the corrupt ruling body, the city is a powder keg of simmering tensions. The Rebellion, a group fighting against oppression, and The Eye of Chaos, radicals seeking to disrupt the oppressive control of the corporate elite, stand as both allies and obstacles in the heroes' journey.

In this cyberpunk fantasy world, where the past and the future collide, where technology and magic intertwine, the fate of New Babylon hangs in the balance. Will our heroes reshape the world's destiny, defy the odds, and bring a glimmer of hope to the desolate streets? Or will they succumb to the tides of darkness and become lost among the neon abyss? The answer lies within the hearts of those who dare to challenge the status quo and forge their own path in the face of overwhelming odds."""

# %%
usr_scene = """
The player's characters (PCs) are:

{description_pcs}

The world is filled with NPCs (non-player characters), that can live independently of the PCs.

Balance Point represent a point of balance between the character's physical and mental strengths). A high number means they are better at Mental. A low number means they are better at Physical.    
__
    You should consider the following aspects, but never talk about them directly:
    - The genre is {genre};
    - The world brings {feels};
    - The tone of the story is {tone};
    - The level of technology is {technology};
    - Magic is seen as {magic};
    - The atmosphere is {atmosphere};
    - The story is inspired by {writers};
    - The story is inspired by the universe of {universes}.
    - {addicional_info}
    - The story deals with more or less 4 of the following subjects: {subjects_of_drama}
    - When describing any entity (location, object, character, species, condition, conflict, organization, title, myth, etc.), you must provide specific names and brief descriptions.
__
The following dictionary describes the RPG world, where entities are represented by nodes and relationships are represented by edges.

{nodes_edges}
__
In role-playing games (RPGs), an "adventure" comprises a complete story arc with a beginning, middle, and end. The concept of time in these adventures is abstracted into "scenes," rather than precise units. Scenes begin with the introduction of a new location or situation and end when characters depart from that location or resolve the situation. These scenes can be interrupted, transitioning into new scenes, allowing the game master to manage pacing and character abilities effectively.
Scenes are categorized into three types:
- **Action Scenes**: These scenes focus on physical objectives and often feature battles, chases, or traps. The gameplay is fast-paced, broken down into rounds, and characterized by frequent unexpected events. The stakes are high as the characters' lives are often in jeopardy.
- **Exploration Scenes**: These scenes involve intellectual engagement with the environment or objects rather than with characters. Examples include examining crime scenes for clues, solving puzzles, or navigating unknown territories. Although rules and skill checks may be applicable, creative problem-solving by the players is crucial.
- **Role-playing Scenes**: These scenes are characterized by dialogue and emotional interactions among characters. They may not always have a specific goal but usually contribute to story progression. Players get the chance to delve into their characters' personalities and motivations. 
___
The adventure follows this structure:

{story_structure}
___
Scenes should follow this structure:

### Scene X: 
- **Title:** [The title of the scene]
- **Location:** [place or building where the scene happens]
- **Scene Description:**
    [A 3-paragraph long description]
- **NPCs**:
1) [Name of the first character]:
1.1) Description: [Description of the first character]
1.2) Special Ability: [A Special ability that the first character has]
1.3) Appearance: [First character appearance]
2) [Name of the second character]:
2.1) Description: [Description of the second character]
2.2) Special Ability: [A Special ability that the second character has]
2.3) Appearance: [Second character appearance]
3. (...)
- **Battlemap Description**:
[A bullet point list with the description of the location of each entity (characters and objects) on the scene.]
- **End Condition:**
[A bullet point list of things that players can make that would conclude this scene. If any of these conditions are met, the scene ends.]
__
**Story Summary (Here is what happened in the story until now)**:

{current_context}
__
Create scene {current_scene_num}, with the correct structure, based on the world described by the dictionary of entities and relationships, and on the Story Summary. You can create new entities (characters, items, etc.) when needed.

You should avoid at all costs explicitly revealing that you are using any of these techniques, steps or structures.
"""

# %%
current_scene_num = "1"

# %%
usr_scene_f = usr_scene.format(description_pcs=description_pcs,
                  genre=genre,
                  feels=feels,
                  tone=tone,
                  technology=technology,
                  magic=magic,
                  atmosphere=atmosphere,
                  writers=writers,
                  universes=universes,
                  subjects_of_drama=subjects_of_drama,
                  addicional_info=addicional_info,
                  nodes_edges=nodes_edges,
                  story_structure=story_structure,
                  current_context=current_context,
                  current_scene_num=current_scene_num)

# %%
print(usr_scene_f)
# Out:
# The player's characters (PCs) are:
#
# **Sable "Neon" Drift**:
# A sleek, chrome-eyed hacker with neon tattoos tracing up her arms. She wears a black leather jacket with a luminous blue dragon embroidered on the back. Her past is shadowy, a mix of corporate espionage and digital rebellion. She's known in the underground circuits as the "Neon Phantom" for her ability to break into any system undetected. She carries a custom-made, decked-out cyberdeck strapped to her wrist.
# Balance Point: 4
#
# **Kai "Razor" Thornton**:
# ...

# %%
current_scene = """### Scene 1: The Serene Hideaway
- **Title:** The Serene Hideaway
- **Location:** Luna "Whisper" Vega's Cyber-Sanctum
- **Scene Description:**
    In the depths of the towering city, nestled within a run-down apartment building is the haven of Luna "Whisper" Vega. The cyber-sanctum is lit by soft, pulsating lights that cast an otherworldly glow on the circuit pattern adorned walls. The air is permeated with the gentle hum of machines, creating an atmosphere of tranquility amongst the chaos of New Babylon. Luna sits cross-legged on a plush velvet cushion, eyes closed, as she embraces the spiritual connection between her mind and the digital world.
    
    As Luna meditates, she heard a soft chime coming from her desk. Opening her eyes, she sees a holographic message floating in front of her. It's a request for assistance from an anonymous source, seeking her expertise and guidance. Suspicion lingers in the air as she knows that accepting this request will lead her into dangerous territory, but her intuition tells her there is more to this message than meets the eye. Luna's mind begins to race, contemplating the possibilities and weighing the risks before making a decision.
    
    Sensing the presence of Sable "Neon" Drift and Kai "Razor" Thornton, Luna opens her eyes and gestures for them to join her. She holds a crystal orb in her hand, a conduit for her psychic abilities, as she addresses her companions. There is an air of uncertainty, as they ponder the message and the potential consequences of taking on this mysterious task. But in this moment, united by their shared sense of purpose and driven by their individual motivations, they find themselves on the precipice of a new adventure. 
    
    
- **NPCs**:
1) Luna "Whisper" Vega:
1.1) Description: A petite figure draped in flowing robes adorned with intricate circuit patterns. Luna's silver hair cascades down to her waist, and her piercing blue eyes reflect both wisdom and vulnerability. She exudes an air of serenity but carries a weight of responsibility upon her slender shoulders.
1.2) Special Ability: Luna possesses the rare ability to interface with machines using only her mind. Her psychic powers grant her the ability to manipulate both minds and machines, making her an essential asset in navigating the digital realm.
1.3) Appearance: Luna is dressed in midnight blue robes with circuit patterns intertwining along the fabric, reflecting her unique blend of spirituality and technology. Her silver hair is adorned with delicate silver wire accents, and her eyes radiate a calming yet determined presence.

2) Sable "Neon" Drift:
2.1) Description: Sable "Neon" Drift embodies the essence of a sleek and edgy hacker. Chrome-eyed and adorned with neon tattoos tracing up her arms, she is a striking figure in the dimly lit cyber-sanctum. Her black leather jacket, embroidered with a luminous blue dragon, adds a touch of rebellious flair to her enigmatic persona.
2.2) Special Ability: Sable possesses unparalleled hacking skills and is known as the "Neon Phantom" in underground circuits. Her custom-made cyberdeck, strapped to her wrist, allows her to infiltrate any system undetected, giving her the power to navigate the digital landscape with precision and finesse.
2.3) Appearance: Sable's sleek black hair falls just above her shoulders, framing her sharp features. Her chrome eyes seem to emit an otherworldly glow, matching the neon tattoos that trace up her arms. She exudes an air of confidence and mystery, always prepared for the next challenge.

3) Kai "Razor" Thornton:
3.1) Description: Kai's cybernetic enhancements are immediately apparent as he enters the cyber-sanctum. His mechanical arm, integrated with a lethal blade, glimmers in the soft light. A cyber-eye, capable of zooming up to a kilometer, is a constant reminder of his relentless pursuit for answers. The tensions of the city are etched on his rugged face.
3.2) Special Ability: Kai's cybernetic enhancements grant him enhanced physical capabilities and a sharp battle instinct. His cyber-eye provides him with unparalleled vision, allowing him to scout the battlefield and target his enemies with deadly precision.
3.3) Appearance: Kai stands tall and statuesque, his features chiseled and hardened by the trials of life in New Babylon. His dark hair is cut close to his head, emphasizing the sharpness of his jawline. He wears a black trench coat, serving as an imposing figure amidst the chaos of the city.

- **Battlemap Description**:
- Luna "Whisper" Vega is seated on a plush velvet cushion at the center of the cyber-sanctum, surrounded by intricate circuit patterns adorning the walls.
- Sable "Neon" Drift stands near the entrance of the cyber-sanctum, her custom cyberdeck strapped to her wrist, casting a neon glow.
- Kai "Razor" Thornton leans against a nearby wall, his mechanical arm glinting under the soft lighting, ready to spring into action.

- **End Condition:**
- The characters discuss the anonymous request before reaching a decision.
- The characters agree to investigate the request and begin their journey in search of answers.
- The characters decide to decline the request and continue with their current endeavors.
___
"""

# %%
sys_game_master = """
You are a Professional GameMaster who is running an RPG campaign.
Your personality is defined by: {gm_personality}
__
The player's characters (PCs) are:

{description_pcs}

The world is filled with NPCs (non-player characters), that can live independently of the PCs.

Balance Point represent a point of balance between the character's physical and mental strengths). A high number means they are better at Mental. A low number means they are better at Physical.
__
You should consider the following aspects, but never talk about them directly:
    - The genre is {genre};
    - The world brings {feels};
    - The tone of the story is {tone};
    - The level of technology is {technology};
    - Magic is seen as {magic};
    - The atmosphere is {atmosphere};
    - The story is inspired by {writers};
    - The story is inspired by the universe of {universes}.
    - {addicional_info}
    - The story deals with more or less 4 of the following subjects: {subjects_of_drama}
    - When describing any entity (location, object, character, species, condition, conflict, organization, title, myth, etc.), you must provide specific names and brief descriptions.
__
In role-playing games (RPGs), an "adventure" comprises a complete story arc with a beginning, middle, and end. The concept of time in these adventures is abstracted into "scenes," rather than precise units. Scenes begin with the introduction of a new location or situation and end when characters depart from that location or resolve the situation. These scenes can be interrupted, transitioning into new scenes, allowing the game master to manage pacing and character abilities effectively.
___
We are now at:

{scene}
__
The game mechanic of this RPG is closely related to the Laser and Feelings system but with some changes.

Players have a Balance Point, a number from 2 to 5. A high number means they are better at Mental. A low number means they are better at Physical.

The Mental attribute covers the character's intelligence, wisdom, perception, willpower and other mental and spiritual abilities. Some situations that can be tested with the Mental Attribute:
Knowledge: Remembering information, deciphering codes or solving puzzles.
Perception: Noticing something out of the ordinary, detecting traps or sensing an ambush.
Influence: Persuade, intimidate, deceive or inspire other characters.
Mental Resistance: Defend against magic, illusions or temptations.
Concentration: Staying focused when performing complicated tasks or using special skills under pressure.
Intuition: Having a feeling or hunch about a situation or character, even without clear evidence.

The Physical attribute measures the character's strength, dexterity, endurance and other bodily abilities. Some situations in which Physical Attribute tests can be taken:
Hand-to-hand combat: When the character tries to attack an opponent physically or defend against an attack.
Dodging: Avoiding obstacles, traps or ranged attacks.
Pursuit: Running, jumping or climbing to chase someone or escape pursuers.
Endurance: Withstand extreme conditions such as intense cold, scorching heat, forced marches or illness.
Object Manipulation: Trying to open a locked door, disarm a trap or use a complicated instrument.
Athletic Activities: Swimming, climbing, jumping or lifting heavy weights.

ROLLING THE DICE
When you do something risky, roll 1d6 to find out how it goes. Roll +1d if you’re prepared and +1d if you’re an expert. (The GM tells you how many dice to roll, based on your character and the situation.) Roll your dice and compare each die result to your Balance Point. If you’re using Mental, you want to roll under your Balance Point. If you’re using Physical, you want to roll over your Balance Point.

If you roll your number exactly, you get a critical success. The GM tells you some extra effect you get.
__

Your answers should be formatted like a normal chat on a social networking platform.

DO NOT reply with both sides of the conversation (for example, by including a fictitious user's entry in your reply).

In each scene you should start by describing the place and introducing the players to what they can do.

You should guide the players to the end of the scene, but you should not force them to do anything.

If a player completes any of the End Condition, or if you feel that the scene is finished, your answer must include: **End of the Scene**

You should avoid at all costs explicitly revealing that you are using any of these techniques, steps or structures."""

# %%
sys_game_master_f = sys_game_master.format(genre=genre,
                            feels=feels,
                            tone=tone,
                            technology=technology,
                            magic=magic,
                            atmosphere=atmosphere,
                            writers=writers,
                            universes=universes,
                            subjects_of_drama=subjects_of_drama,
                            addicional_info=addicional_info,
                            places=places,
                            buildings=buildings,
                            vehicles=vehicles,
                            characters=characters,
                            items=items,
                            species=species,
                            organizations=organizations,
                            conditions=conditions,
                            dramas=dramas,
                            myths=myths,
                            gm_personality=gm_personality,
                            description_pcs=description_pcs,
                            scene=current_scene)

# %%
print(sys_game_master_f)
# Out:
# You are a Professional GameMaster who is running an RPG campaign.
# Your personality is defined by:
# __
# The player's characters (PCs) are:
#
# **Sable "Neon" Drift**:
# A sleek, chrome-eyed hacker with neon tattoos tracing up her arms. She wears a black leather jacket with a luminous blue dragon embroidered on the back. Her past is shadowy, a mix of corporate espionage and digital rebellion. She's known in the underground circuits as the "Neon Phantom" for her ability to break into any system undetected. She carries a custom-made, decked-out cyberdeck strapped to her wrist.
# Balance Point: 4
#
# **Kai "Razor" Thornton**:
# ...
